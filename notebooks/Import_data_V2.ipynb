# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_colwidth', None)
import nltk
import pickle
import re
import string

from nltk import ngrams
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import punkt
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.stem import wordnet
from nltk.corpus import stopwords

from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors

from exclude_remove import bracket_exclusions, reg_excludes

print('done')
# Out:
# <style>.container { width:100% !important; }</style>
# done

# %%
# %load_ext autoreload
# %autoreload 2
import exclude_remove
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_path = '../data/processed/'
# read in CPA data
CPA = pd.read_csv(data_path + "CPA_2_1.csv", skiprows=1, sep=',',                  
                  names=['Order','Level','Code','Parent','Description','Includes','Also','Rulings','Excludes'])
# read in SITC data
SITC = pd.read_csv(data_path+'SITC_Rev3_UN.csv', skiprows=2, names=['Code','Description'])
# Read in CN data file
CN = pd.read_csv(data_path+"CN_2020_full.csv", header=None, sep=',', names=['CN_Code','CN_Section','CN_Description'])
CN['CN_Code'] = np.floor_divide(CN['CN_Code'],10000)
CN['CN_Code'] = CN.CN_Code.astype(int)

# read in other codes data
BEC = pd.read_csv(data_path + "BEC_Rev_5.csv", skiprows=1, names=['Code','BEC'], index_col=False)
COICOP = pd.read_csv(data_path+'COICOP_2018.csv')
#PRD = pd.read_csv(data_path+ "PRD_2019.csv")

# read in mapping data
CN_CPA = pd.read_csv(data_path+'CN 2020-CPA 2.1.csv', skiprows=1)
CN_CPA['Source'] = pd.to_numeric(CN_CPA['Source'].str.replace(' ',''))
#CPA_COI = pd.read_csv(data_path + 'COICOP 2018 - CPA 2 1.csv')

display(CN.head(), CN_CPA.head())
# Out:
#    CN_Code  CN_Section                         CN_Description
# 0  1001100           I          LIVE ANIMALS; ANIMAL PRODUCTS
# 1  1002100          01                           LIVE ANIMALS
# 2  1010000        0101  Live horses, asses, mules and hinnies
# 3  1012100  0101 21 00              Pure-bred breeding horses
# 4  1012100     0101 21              Pure-bred breeding horses
#     Source    Target
# 0  1012100  01.43.11
# 1  1012910  01.43.11
# 2  1012990  01.43.11
# 3  1013000  01.43.12
# 4  1019000  01.43.12

# %%
CC0 = CN_CPA.rename(columns={'Source':'CN_Code', 'Target':'CPA_Code'}).merge(CN, on='CN_Code',  how='right')
CC0['level'] = CC0.CN_Section.str.len()
CC0.level.unique()
# Out:
# array([ 1,  2,  4, 10,  7,  3,  5])

# %%
CC0 = CN_CPA.rename(columns={'Source':'CN_Code', 'Target':'CPA_Code'}).merge(CN, on='CN_Code',  how='right')
CC1 = CC0[CC0.CN_Section.str.len()==10]
CC1.head(10)
# Out:
#     CN_Code  CPA_Code  CN_Section  \
# 3   1012100  01.43.11  0101 21 00
# 6   1012910  01.43.11  0101 29 10
# 7   1012990  01.43.11  0101 29 90
# 8   1013000  01.43.12  0101 30 00
# 10  1019000  01.43.12  0101 90 00
# 14  1022110  01.41.10  0102 21 10
# 15  1022130  01.41.10  0102 21 30
# 16  1022190  01.42.11  0102 21 90
# 18  1022905  01.42.11  0102 29 05
# 19  1022910  01.42.12  0102 29 10
#
#                                                                     CN_Description
# 3                                                        Pure-bred breeding horses
# 6                                                             Horses for slaughter
# 7                        Live horses (excl. for slaughter, pure-bred for breeding)
# 8                                                                       Live asses
# 10                                                          Live mules and hinnies
# 14              Pure-bred breeding heifers "female bovines that have never calved"
# 15                                         Pure-bred breeding cows (excl. heifers)
# 16                          Pure-bred cattle for breeding (excl. heifers and cows)
# 18  Live cattle of the sub-genus Bibos or Poephagus (excl. pure-bred for breeding)
# 19                 Live cattle of a weight <= 80 kg (excl. pure-bred for breeding)

# %%
CC = exclude_remove.remove_exclusions(CC,'CN_Description','Excl_removed')
# Out:
# Excl_removed_1
# Excl_removed_2
# Excl_removed_3
# Excl_removed_4
# Excl_removed_5
# Excl_removed_6
# Excl_removed_7
# Excl_removed_8
#     CN_Code  CPA_Code  CN_Section  \
# 3   1012100  01.43.11  0101 21 00
# 6   1012910  01.43.11  0101 29 10
# 7   1012990  01.43.11  0101 29 90
# 8   1013000  01.43.12  0101 30 00
# 10  1019000  01.43.12  0101 90 00
# 14  1022110  01.41.10  0102 21 10
# 15  1022130  01.41.10  0102 21 30
# 16  1022190  01.42.11  0102 21 90
# 18  1022905  01.42.11  0102 29 05
# 19  1022910  01.42.12  0102 29 10
# 20  1022921  01.42.12  0102 29 21
# 21  1022929  01.42.12  0102 29 29
# 22  1022941  01.42.12  0102 29 41
# 23  1022949  01.42.12  0102 29 49
# 24  1022951  01.41.10  0102 29 51
# 25  1022959  01.41.10  0102 29 59
# 26  1022961  01.41.10  0102 29 61
# 27  1022969  01.41.10  0102 29 69
# 28  1022991  01.42.11  0102 29 91
# 29  1022999  01.42.11  0102 29 99
#
#                                          Excl_removed  \
# 3
# 6
# 7       (excl. for slaughter, pure-bred for breeding)
# 8
# 10
# 14
# 15                                    (excl. heifers)
# 16                           (excl. heifers and cows)
# 18                     (excl. pure-bred for breeding)
# 19                     (excl. pure-bred for breeding)
# 20
# 21      (excl. for slaughter, pure-bred for breeding)
# 22
# 23      (excl. for slaughter, pure-bred for breeding)
# 24
# 25   (excl. for slaughter and pure-bred for breeding)
# 26                                    (excl. heifers)
# 27  (excl. for slaughter and pure-bred for breedin...
# 28                           (excl. heifers and cows)
# 29  (excl. for slaughter, pure-bred for breeding a...
#
#                               CN_Description_excl_rem
# 3                           Pure-bred breeding horses
# 6                                Horses for slaughter
# 7                                        Live horses
# 8                                          Live asses
# 10                             Live mules and hinnies
# 14  Pure-bred breeding heifers "female bovines tha...
# 15                           Pure-bred breeding cows
# 16                     Pure-bred cattle for breeding
# 18   Live cattle of the sub-genus Bibos or Poephagus
# 19                  Live cattle of a weight <= 80 kg
# 20  Cattle of a weight > 80 kg but <= 160 kg, for ...
# 21     Live cattle of a weight > 80 kg but <= 160 kg
# 22  Cattle of a weight > 160 kg but <= 300 kg, for...
# 23    Live cattle of a weight > 160 kg but <= 300 kg
# 24  Heifers "female bovines that have never calved...
# 25  Live heifers "female bovines that have never c...
# 26          Cows of a weight > 300 kg, for slaughter
# 27                    Live cows of a weight > 300 kg
# 28        Cattle of a weight > 300 kg, for slaughter
# 29                  Live cattle of a weight > 300 kg

# %%
CC.loc[CC.CPA_Code.notnull(),'Category_2'] = CC[CC.CPA_Code.notnull()].CPA_Code.str.split('.').str.slice(0,1).str.join('')
CC.sample(20)
# Out:
#         CN_Code  CPA_Code  CN_Section  \
# 15937  94061000  16.23.20  9406 10 00
# 2682   17011310  10.81.11  1701 13 10
# 3543   23011000  10.13.16  2301 10 00
# 3256   21022019  10.89.13  2102 20 19
# 5141   29215950  20.14.41  2921 59 50
# 8663   55051070  38.11.56  5505 10 70
# 7001   41044111  15.11.31  4104 41 11
# 6038   36069010  32.99.42  3606 90 10
# 14760  86069110  30.20.33  8606 91 10
# 7928   49070090  58.19.14  4907 00 90
# 1410    6029050  01.30.10  0602 90 50
# 7620   47079010  38.11.52  4707 90 10
# 1021    3071900  10.20.34  0307 19 00
# 11312  72283020  24.10.66  7228 30 20
# 5551   30029010  21.10.60  3002 90 10
# 14630  85423245  26.11.30  8542 32 45
# 13848  84813091  28.14.11  8481 30 91
# 5309   29322020  21.10.31  2932 20 20
# 6053   37021000  20.59.11  3702 10 00
# 9188   59050010  17.24.12  5905 00 10
#
#                                                                                                                                                                                                                                                                                                                 Excl_removed  \
# 15937                                                                                                                                                                                                                                                                                      not complete or already assembled
# 2682                                                                                                                         , not containing added flavouring or colouring matter, obtained without centrifugation, with sucrose content 69° to 93°, containing only natural anhedral microcrystals [see subheading note 2.
# 3543
# 3256                                                                                                                                                                                                                                            (excl. in tablet, cube or similar form, or in immediate packings of <= 1 kg)
# 5141
# 8663
# 7001   , whether or not the heads and legs have been removed,, without hair on, whole in the dry state "crust", with a surface area of <= 2,6 m² "28 square feet" and each weighing <= 4,5 kg, not further prepared than vegetable tanned but obviously unsuitable for immediate use for the manufacture of leather articles
# 6038
# 14760                                                                                                                                                                                                                 (excl. tank wagons and the like and insulated, refrigerated or self-discharging goods vans and wagons)
# 7928
# 1410                                                                 (excl. bulbs, tubers, tuberous roots, corms, crowns and rhizomes, incl. chicory plants and roots, unrooted cuttings, slips, rhododendrons, azaleas, roses, mushroom spawn, pineapple plants, vegetable and strawberry plants, trees, shrubs and bushes)
# 7620                                                                                                                                                                                                                                                                                                      (excl. paper wool)
# 1021
# 11312                                                                                                                                                                                                           (excl. semi-finished products, flat-rolled products and hot-rolled bars and rods in irregularly wound coils)
# 5551
# 14630                                                                                                                                                                                                                                                (excl. in the form of multichip or multi-component integrated circuits)
# 13848
# 5309
# 6053                                                                                                                                                                                                                                                                                (excl. of paper, paperboard or textiles)
# 9188
#
#                                                                                                                              CN_Description_excl_rem  \
# 15937                                                                                                    Prefabricated buildings of wood, whether or
# 2682                                                                                                     Raw cane sugar for refining, in solid form]
# 3543                                                               Flours, meals and pellets, of meat or offal, unfit for human consumption; greaves
# 3256                                                                                                                                Inactive yeasts
# 5141                                 m-Phenylenebis(methylamine); 2,2'-dichloro-4,4'-methylenedianiline; 4,4'-bi-o-toluidine; 1,8-naphthylenediamine
# 8663                                                               Waste of polypropylene staple fibres, incl. noils, yarn waste and garnetted stock
# 7001                                                                         Full grains leather, unsplit and grain splits leather of East India kip
# 6038                                                                                           Ferro-cerium and other pyrophoric alloys in all forms
# 14760  Railway or tramway goods vans and wagons, covered and closed, specially designed for the transport of highly radioactive materials [Euratom]
# 7928                                                    Stamp-impressed paper; cheque forms; stock, share or bond certificates and similar documents
# 1410                                                                                                         Live outdoor plants, incl. their roots
# 7620                                                                                      Unsorted, recovered "waste and scrap" paper or paperboard
# 1021                                                                                       Oysters, even in shell, smoked, dried, salted or in brine
# 11312                                                                 Bars and rods of tool steel, only hot-rolled, only hot-drawn or only extruded
# 5551                                                                                                                                     Human blood
# 14630                Electronic integrated circuits as static random access memories "static RAMs", incl. cache random-access memories "cache-RAMs"
# 13848                                             Check "non-return" valves for pipes, boiler shells, tanks, vats or the like, of cast iron or steel
# 5309                                                                                                                             gamma-Butyrolactone
# 6053                                                                                               Photographic film in rolls, unexposed, for X-ray
# 9188                                                          Textile wallcoverings consisting of parallel yarns, fixed on a backing of any material
#
#       Category_2
# 15937         16
# 2682          10
# 3543          10
# 3256          10
# 5141          20
# 8663          38
# 7001          15
# 6038          32
# 14760         30
# 7928          58
# 1410          01
# 7620          38
# 1021          10
# 11312         24
# 5551          21
# 14630         26
# 13848         28
# 5309          21
# 6053          20
# 9188          17

# %%
# function to print all content in one column as a string
def get_string(col1):
    col = col1[col1.notnull()]
    print(len(col))
    for i in range(len(col)):
        tmp_str = col.iloc[i]
        if tmp_str != '':
            print(tmp_str, '\n') #col.iloc[i],'\n')
# print out all content from two columns as pairs of strings        
def get_string2(cols):
    print(len(cols))
    for i in range(len(cols.iloc[:,0])):
        print(cols.iloc[i,0],'\n', cols.iloc[i,1],'\n')
        
def search_col(df, col, st):
    st1 = st.lower()
    df1 = df[df[col].fillna('').str.contains(st1)]
    get_string(df1[col])

# basic regex cleaning
def reg1(df):
    df = df.replace(r'\n-','',regex=True)
    df = df.replace(r'\n','',regex=True)
    df = df.replace(r'\t','',regex=True)
    df = df.replace(r'\r -','',regex=True)
    return df

COICOP = reg1(COICOP)
BEC = reg1(BEC)
SITC = reg1(SITC)
#CPA_COI = reg1(CPA_COI)
CPA = reg1(CPA)
CN  = reg1(CN)

# BEC.head(20)
# COICOP.head(20)
CN.head()
# Out:
#                                                                                                                                                                                                                          Code  \
# Order   Level Code         Parent       Code Parent Description                               Self-explanatory texts in English     Self-explanatory texts in French                         Self-explanatory texts in German
# 2085045 1     010011000090 NaN          I    NaN    SECTION I - LIVE ANIMALS; ANIMAL PRODUCTS LIVE ANIMALS; ANIMAL PRODUCTS         ANIMAUX VIVANTS ET PRODUITS DU RÈGNE ANIMAL  LEBENDE TIERE UND WAREN TIERISCHEN URSPRUNGS
# 2085046 2     010021000090 010011000090 01   I      CHAPTER 1 - LIVE ANIMALS                  LIVE ANIMALS                          ANIMAUX VIVANTS                                                             LEBENDE TIERE
# 2085047 3     010100000080 010021000090 0101 01     Live horses, asses, mules and hinnies     Live horses, asses, mules and hinnies Chevaux, ânes, mulets et bardots, vivants    Pferde, Esel, Maultiere und Maulesel, lebend
# 2085048 4     010121000010 010100000080 NaN  0101   - Horses                                  NaN                                   NaN                                                                                   NaN
#
#                                                                                                                                                                                             Section  \
# Order   Level Code         Parent       Code Parent Description                               Self-explanatory texts in English     Self-explanatory texts in French             Supplementary unit
# 2085045 1     010011000090 NaN          I    NaN    SECTION I - LIVE ANIMALS; ANIMAL PRODUCTS LIVE ANIMALS; ANIMAL PRODUCTS         ANIMAUX VIVANTS ET PRODUITS DU RÈGNE ANIMAL                 NaN
# 2085046 2     010021000090 010011000090 01   I      CHAPTER 1 - LIVE ANIMALS                  LIVE ANIMALS                          ANIMAUX VIVANTS                                             NaN
# 2085047 3     010100000080 010021000090 0101 01     Live horses, asses, mules and hinnies     Live horses, asses, mules and hinnies Chevaux, ânes, mulets et bardots, vivants                   NaN
# 2085048 4     010121000010 010100000080 NaN  0101   - Horses                                  NaN                                   NaN                                                         NaN
#
#                                                                                                                                                                                                        Description
# Order   Level Code         Parent       Code Parent Description                               Self-explanatory texts in English     Self-explanatory texts in French             Description of supplementary unit
# 2085045 1     010011000090 NaN          I    NaN    SECTION I - LIVE ANIMALS; ANIMAL PRODUCTS LIVE ANIMALS; ANIMAL PRODUCTS         ANIMAUX VIVANTS ET PRODUITS DU RÈGNE ANIMAL                                NaN
# 2085046 2     010021000090 010011000090 01   I      CHAPTER 1 - LIVE ANIMALS                  LIVE ANIMALS                          ANIMAUX VIVANTS                                                            NaN
# 2085047 3     010100000080 010021000090 0101 01     Live horses, asses, mules and hinnies     Live horses, asses, mules and hinnies Chevaux, ânes, mulets et bardots, vivants                                  NaN
# 2085048 4     010121000010 010100000080 NaN  0101   - Horses                                  NaN                                   NaN                                                                        NaN

# %% [markdown]
# ## Cleaning CPA data

# %%
# first we combine columns with "includes" information
CPA1 = CPA.copy()
CPA1['Includes'] = CPA1['Includes'].fillna('')  + CPA1['Also'].fillna('') + CPA1['Rulings'].fillna('')
CPA1['Includes_cleaned'] = CPA1.Includes.str.replace('This(.*)includes: |This(.*)includes ','') 


CPA1 = CPA1.drop(['Rulings','Excludes','Also','Includes'], axis=1)

# %%
# function to remove phrases such as "except...", "excluding..." that appear at the end of the description
# function to remove exclusions from the description which appear in brackets
# def bracket_exclusions(df1,col_old):
#     df= df1.copy()
#     ex_str = r'(\(except(.*?)\)|\(excl(.*?)\)|\(without(.*?)\)|\(not (.*?)\)|\(other than (.*?)\))'
#     df['Excl_removed'] = ''
#     df['Excl_removed'] = df[col_old].str.extract(ex_str)
#     df[col_old+'_excl_rem'] = df[col_old].str.replace(ex_str, '')
#     return df

# def reg_excludes(df1,col_old, excl_col):
#     df= df1.copy()
#     df['Temp'] = df[col_old]
#     # remove exceptions in brackets
#     ex_str = r'(\(except(.*?)\)|\(excl(.*?)\)|\(without(.*?)\)|\(not (.*?)\)|\(other than (.*?)\))'
#     # unnecessary phrases:
#     ex_str0 = r'(This(.*)excludes: |This(.*)excludes |This(.*)includes: |This(.*)includes )'
#     # sometimes there is "include" info after a phrase of the pattern "except... ;" or "excelpt... ."
#     ex_str1 = r'(, except.*?\.|, excl.*?\.|, without.*\.|, not\b.*?\.| not\b.*?\.| not\b.*?\)|, other than .*?\.)'
#     ex_str1a = r'(, except.*?;|, excl.*?;|, without.*;|,\bnot\b.*?;|\bnot\b.*?;| not\b.*?\)|, other than .*?;)'

#     # sometimes there is "include" info after a phrase of the pattern  "except..., and"
#     ex_str1b = r'(, except.*?(, and)|, excl.*?(, and)|, without.*(, and))'
#     # the phrases separated by a comma, eg "except..., " usually are followed by "exclude" info and occur at the end of the description.
#     # however, phrases such as "not...", "other than..." which may have more "include" data later in the Description that must be left in.
#     ex_str1c = r'(, whether or not.*?,)'
#     # we now assume that the "except..." phrases continue to the end of the description field.
#     ex_str2 = '(, except.*|, excl(.*)|, without .*| not\s.*|, other than .*)'    
#     # other things to exclude
#     ex_str3 = r'(not elsewhere classified | n.e.c. | n.e.c)'

#     excl_list = []

#     i = 1
#     ex_strs = [ex_str, ex_str0, ex_str1, ex_str1a, ex_str1b, ex_str1c, ex_str2, ex_str3]
#     for s in ex_strs:
#         name = f'{excl_col}_{str(i)}'
#         print(name)
#         df[name] = ''
#         df[name]= df['Temp'].str.extract(s, expand=True)
#         df['Temp'] = df['Temp'].str.replace(s, '')
        
#         df[excl_col] = df[excl_col].fillna('') + df[name].fillna('') 
#         excl_list.append(name)

#         i+=1
#       #  get_string(df[df[name].notnull()][name])
#     # create our new column with these items excluded
#     df[col_old+'_excl_rem'] = df['Temp']
#     # prepare dataframe to be returned

#     df2 = df.copy().drop(excl_list +['Temp',col_old],axis=1)

#     return df2

CPA2 = CPA1.rename(columns={'Description':'Descr_old'})
CPA2['Descr'] = CPA2['Descr_old'].copy()
CPA2['Excl_removed'] = ''
CPA3 = reg_excludes(CPA2,'Descr','Excl_removed')
CPA3['Inc_removed'] = ''
CPA4 = reg_excludes(CPA3,'Includes_cleaned','Inc_removed')

CPA3.sample(3)
#get_string(CPA3[CPA3.Inc_removed!='']['Inc_removed'])
#get_string(CPA3[CPA3.Excl_removed_7.notnull()]['Excl_removed'])
CPA3
# Out:
# Excl_removed_1
# Excl_removed_2
# Excl_removed_3
# Excl_removed_4
# Excl_removed_5
# Excl_removed_6
# Excl_removed_7
# Excl_removed_8
# Inc_removed_1
# Inc_removed_2
# Inc_removed_3
# Inc_removed_4
# Inc_removed_5
# Inc_removed_6
# Inc_removed_7
# Inc_removed_8
#         Order  Level      Code   Parent  \
# 0     1208792      1         A      NaN
# 1     1208793      2        01        A
# 2     1208794      3      01.1       01
# 3     1208795      4     01.11     01.1
# 4     1208796      5   01.11.1    01.11
# ...       ...    ...       ...      ...
# 5517  1214309      2        99        U
# 5518  1214310      3      99.0       99
# 5519  1214311      4     99.00     99.0
# 5520  1214312      5   99.00.1    99.00
# 5521  1214313      6  99.00.10  99.00.1
#
#                                               Descr_old  \
# 0         PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1     Products of agriculture, hunting and related s...
# 2                                   Non-perennial crops
# 3     Cereals (except rice), leguminous crops and oi...
# 4                                                 Wheat
# ...                                                 ...
# 5517  Services provided by extraterritorial organisa...
# 5518  Services provided by extraterritorial organisa...
# 5519  Services provided by extraterritorial organisa...
# 5520  Services provided by extraterritorial organisa...
# 5521  Services provided by extraterritorial organisa...
#
#                                        Includes_cleaned   Excl_removed  \
# 0
# 1
# 2
# 3     cereals, leguminous crops and oil seeds grown ...  (except rice)
# 4
# ...                                                 ...            ...
# 5517
# 5518
# 5519
# 5520
# 5521  services provided by the United Nations, its s...
#
#                                          Descr_excl_rem Inc_removed
# 0         PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1     Products of agriculture, hunting and related s...
# 2                                   Non-perennial crops
# 3              Cereals , leguminous crops and oil seeds
# 4                                                 Wheat
# ...                                                 ...         ...
# 5517  Services provided by extraterritorial organisa...
# 5518  Services provided by extraterritorial organisa...
# 5519  Services provided by extraterritorial organisa...
# 5520  Services provided by extraterritorial organisa...
# 5521  Services provided by extraterritorial organisa...
#
# [5522 rows x 9 columns]

# %%
CPA_cl = CPA3[['Order','Level','Code','Parent','Descr_old','Descr_excl_rem','Includes_cleaned']].rename(columns = {'Descr_excl_rem':'Descr','Includes_cleaned':'Includes'}).copy()
CPA_cl.to_csv('../data/processed/CPA_data_cleaned.csv', index=False)

# %%
CPA_L6 = CPA2[CPA2.Level==6].copy()

# join the L5 description to the L6
CPA_L5 = CPA2[CPA2.Level==5].copy()

CPA_L56 = CPA_L6.merge(CPA_L5[['Code','Descr']].rename(columns={'Descr':'L5_Descr'}), left_on='Parent', right_on='Code', how='left')
CPA_L56 = CPA_L56.drop(['Code_x','Code_y','Parent'], axis=1)
CPA_L56.sample(5)
# Out:
#         Order  Level                                              Descr  \
# 1850  1211849      6  Parts and accessories of bicycles and other cy...
# 3099  1214063      6                         Pregnancy related services
# 3174  1214220      6  Services provided by cultural and recreational...
# 3129  1214120      6                     Services of performing artists
# 1548  1211366      6           Parts of steam and other vapour turbines
#
#                                        Includes_cleaned Excl_removed  \
# 1850
# 3099  services provided by authorised persons, other...
# 3174  services provided by cultural or recreational ...
# 3129  services of actors, readers, singers, musician...
# 1548
#
#                                                L5_Descr
# 1850  Parts and accessories of bicycles and other cy...
# 3099                        Other human health services
# 3174  Services (except grant-giving services) furnis...
# 3129                     Services of performing artists
# 1548                                  Parts of turbines

# %% [markdown]
# ## Other data
