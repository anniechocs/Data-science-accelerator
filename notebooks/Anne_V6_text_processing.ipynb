# %% [markdown]
# # Text Processing for Accelerator project
#
# A simplified pipeline processing text with FastText.
#
# * Load CPA data
# * Basic text cleaning
# * Vectorize (with FastText)
# * Reduce dimension using UMAP, both supervised and unsupervised
# * Predict unclassified data

# %%
# this bit shouldn't be necessary if we pip install -e .   in the parent directory
# %load_ext autoreload
# %autoreload 2

# %%
import functools
from pprint import pprint
from time import time
from IPython.display import display, HTML
import logging
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

from sklearn import metrics
import umap

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express
from imblearn.metrics import classification_report_imbalanced

import text_processing

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Load FastText Pretrained
#
# Note: This requires a fair bit of memory (peaks at about 17.5 GiB)
#
# Recommend shutting down other kernels first, once this has loaded memory usage drops again.
#
# This takes a few minutes to load in.

# %%
wv = text_processing.fetch_fasstext_pretrained(filepath="../../data/wiki.en.bin")
# Out:
# 2020-11-28 11:35:18,409 - text_processing - INFO - Loading FastText pretrained from ../../data/wiki.en.bin
# 2020-11-28 11:39:42,195 - text_processing - INFO - Model loaded

# %% [markdown]
# #### Load in the CPA data

# %%
CPA = text_processing.fetch_files()
# Out:
# 2020-11-28 11:42:39,034 - text_processing - INFO - cleanded CPA File imported

# %%
CPA1 = CPA[CPA.Level.isin({3,4,5,6})][['Code','Descr_old','Descr','Category_0','Category_1','Category_2']].copy()
df = text_processing.clean_col(CPA1, "Descr")
df.drop('Descr',axis=1,inplace=True)
df['Cat'] = df.Category_1
# choose the category for our main classification

df.sample(5)
# Out:
# 2020-11-28 11:42:40,537 - text_processing - INFO - Cleaning column: Descr
#           Code  \
# 4066  49.42.19
# 4674  68.31.11
# 3957  47.00.43
# 3845      46.5
# 1559  20.59.56
#
#                                                                                                                                                                                                              Descr_old  \
# 4066                                                                                                                                                                                            Other removal services
# 4674                                                                                     Residential buildings and associated land sale services on a fee or contract basis, except of time-share ownership properties
# 3957                                                                                                                                                                               Retail trade services of flat glass
# 3845                                                                                                                                               Wholesale trade services of information and communication equipment
# 1559  Pickling preparations; fluxes; prepared rubber accelerators; compound plasticisers and stabilisers for rubber or plastics; catalytic preparations n.e.c.; mixed alkylbenzenes and mixed alkylnaphthalenes n.e.c.
#
#       Category_0 Category_1 Category_2  \
# 4066           4          H         49
# 4674           7          L         68
# 3957           4          G         47
# 3845           4          G         46
# 1559           2          C         20
#
#                                                                                                                                                                        Descr_cleaned  \
# 4066                                                                                                                                                                removal services
# 4674                                                                                                          residential buildings associated land sale services fee contract basis
# 3957                                                                                                                                                retail trade services flat glass
# 3845                                                                                                                    wholesale trade services information communication equipment
# 1559  pickling preparations fluxes prepared rubber accelerators compound plasticisers stabilisers rubber plastics catalytic preparations mixed alkylbenzenes mixed alkylnaphthalenes
#
#      Cat
# 4066   H
# 4674   L
# 3957   G
# 3845   G
# 1559   C

# %% [markdown]
# ### Vectorize CPA data using FastText

# %%
text_to_vec = functools.partial(text_processing.vectorize_text, wv)
df["Descr_cleaned_vectorized"] = df.Descr_cleaned.apply(
    text_to_vec
)

# %% [markdown]
# ## Dimensionality Reduction using UMAP

# %% [markdown]
# ### Unsupervised dimension reduction

# %%
# df["Descr_cleaned_vectorized_low_dimension"] = text_processing.reduce_dimensionality(df.Descr_cleaned_vectorized)

# %% [markdown]
# ### Dimensionality Reduction using UMAP supervised

# %%
df["Descr_cleaned_vectorized_low_dimension"] = text_processing.reduce_dimensionality_supervised(df.Descr_cleaned_vectorized, df.Cat)
# Out:
# 2020-11-28 11:42:58,356 - text_processing - INFO - Now applying umap to reduce dimension
# UMAP(min_dist=0.0, n_components=10, n_neighbors=10, random_state=3052528580,
#      verbose=10)
# Construct fuzzy simplicial set
# Sat Nov 28 11:42:58 2020 Finding Nearest Neighbors
# Sat Nov 28 11:42:58 2020 Building RP forest with 9 trees
# Sat Nov 28 11:42:59 2020 NN descent for 12 iterations
# 	 0  /  12
# 	 1  /  12
# 	 2  /  12
# 	 3  /  12
# 	 4  /  12
# 	 5  /  12
# 	 6  /  12
# 	 7  /  12
# 	 8  /  12
# 	 9  /  12
# Sat Nov 28 11:43:05 2020 Finished Nearest Neighbor Search
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   return f(**kwargs)
# Sat Nov 28 11:43:09 2020 Construct embedding
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Sat Nov 28 11:43:29 2020 Finished embedding

# %% [markdown]
# ### Split the CPA data into a training set and a test set

# %%
# Split dataset into training set and test set
train_set, test_set = train_test_split(df.copy(), test_size=0.2, random_state=42)

# %% [markdown]
# # Use the Random Forest Classifier
#
# https://www.datacamp.com/community/tutorials/random-forests-classifier-python
#
# We have already split our data into training and test datasets and used UMAP supervised classification to reduce the dimension on the training set.
# We then used UMAP prediction to reduce the dimension on the test set.
#
# We now use the random forest classifier on the training set, and see how it works on the test set.

# %%
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets 
X_train = np.array(list(train_set["Descr_cleaned_vectorized_low_dimension"].values))
y_train = np.array(list(train_set.Cat.values))

X_test = np.array(list(test_set["Descr_cleaned_vectorized_low_dimension"].values))
y_test = np.array(list(test_set.Cat.values))

clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %% [markdown]
# #### Accuracy

# %%
#Import scikit-learn metrics module for accuracy calculation
y_test = np.array(list(test_set.Cat.values))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9879963065558633

# %%
# get a dataframe of the level 2 descriptions
Cat_descr = text_processing.get_category_description(CPA, 1)
Cat_descr.sample(5)
# Out:
#      Category_1  \
# 4685          M
# 3618          G
# 0             A
# 5516          U
# 3307          D
#
#                                                                             Category_1_descr
# 4685                                         PROFESSIONAL, SCIENTIFIC AND TECHNICAL SERVICES
# 3618  WHOLESALE AND RETAIL TRADE SERVICES; REPAIR SERVICES OF MOTOR VEHICLES AND MOTORCYCLES
# 0                                              PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 5516                          SERVICES PROVIDED BY EXTRATERRITORIAL ORGANISATIONS AND BODIES
# 3307                                            ELECTRICITY, GAS, STEAM AND AIR CONDITIONING

# %%
print(len(y_pred), len(y_test))
test_set['Predicted'] = pd.Series(data=y_pred.tolist(), index=test_set.index)
non_matches0 = test_set[test_set.Predicted != test_set.Cat].drop('Descr_cleaned_vectorized',axis=1)
non_matches1 = non_matches0.merge(Cat_descr, on='Category_1', how='inner')
non_matches = non_matches1.merge(Cat_descr.rename(columns={'Category_1_descr':'Prediced_Cat_descr', 'Category_1':'Predicted'}),
                                 on='Predicted', how='inner')
# Out:
# 1083 1083

# %%
non_matches
# Out:
#         Code  \
# 0   46.46.12
# 1   01.26.12
# 2   01.16.11
# 3   38.12.21
# 4   38.32.13
# 5   38.12.27
# 6   71.20.14
# 7   93.19.12
# 8   85.53.11
# 9   79.90.32
# 10  77.29.15
# 11  82.19.12
# 12  52.29.11
#
#                                                                                 Descr_old  \
# 0   Wholesale trade services of surgical, medical and orthopaedic instruments and devices
# 1                                                      Olives for production of olive oil
# 2                                                           Cotton, whether or not ginned
# 3                       Spent (irradiated) fuel elements (cartridges) of nuclear reactors
# 4               Briquettes n.e.c. (produced from several different industrialwastes etc.)
# 5           Waste and scrap of primary cells, primary batteries and electric accumulators
# 6                                Technical inspection services of road transport vehicles
# 7                                                                    Services of athletes
# 8                                                             Car driving school services
# 9         Reservation services for convention centres, congress centres and exhibit halls
# 10                         Rental and leasing services of textiles, clothing and footwear
# 11                                          Mailing list compilation and mailing services
# 12                                                                   Ship-broker services
#
#     Category_0 Category_1 Category_2  \
# 0            4          G         46
# 1            1          A         01
# 2            1          A         01
# 3            2          E         38
# 4            2          E         38
# 5            2          E         38
# 6            8          M         71
# 7           10          R         93
# 8            9          P         85
# 9            8          N         79
# 10           8          N         77
# 11           8          N         82
# 12           4          H         52
#
#                                                                 Descr_cleaned  \
# 0   wholesale trade services surgical medical orthopaedic instruments devices
# 1                                                 olives production olive oil
# 2                                                              cotton whether
# 3                  spent irradiated fuel elements cartridges nuclear reactors
# 4                   briquettesproduced several different industrialwastes etc
# 5           waste scrap primary cells primary batteries electric accumulators
# 6                       technical inspection services road transport vehicles
# 7                                                           services athletes
# 8                                                 car driving school services
# 9      reservation services convention centres congress centres exhibit halls
# 10                         rental leasing services textiles clothing footwear
# 11                                  mailing list compilation mailing services
# 12                                                       ship-broker services
#
#    Cat  \
# 0    G
# 1    A
# 2    A
# 3    E
# 4    E
# 5    E
# 6    M
# 7    R
# 8    P
# 9    N
# 10   N
# 11   N
# 12   H
#
#                                                                                                                                                                   Descr_cleaned_vectorized_low_dimension  \
# 0     [9.310953140258789, 5.6005353927612305, 6.543834686279297, -0.023517046123743057, 4.097960472106934, 7.09716272354126, 4.504067420959473, 4.323415279388428, 8.958893775939941, 7.982893466949463]
# 1         [7.0381999015808105, 5.458954811096191, 4.1663818359375, 2.1175312995910645, 3.4548428058624268, 7.016144752502441, 5.037139415740967, 3.6507906913757324, 9.4058198928833, 5.878485679626465]
# 2     [9.953943252563477, 5.169009685516357, 3.9541127681732178, -1.5118979215621948, 4.058659553527832, 6.438737392425537, 5.8681769371032715, 5.471585273742676, 7.542972564697266, 6.428776264190674]
# 3         [8.673707962036133, 5.085537433624268, 6.337480545043945, -0.3022427558898926, 4.307536602020264, 7.334295272827148, 3.1383056640625, 4.211902141571045, 8.406109809875488, 8.148168563842773]
# 4     [9.494315147399902, 5.150977611541748, 4.825336933135986, -1.0162200927734375, 4.202905178070068, 6.765171051025391, 4.622105121612549, 5.232601165771484, 7.6984710693359375, 7.1002116203308105]
# 5      [8.263056755065918, 5.1628289222717285, 3.1491007804870605, 0.3126712441444397, 3.2859604358673096, 6.92125940322876, 4.376079559326172, 4.316834926605225, 8.986431121826172, 6.113201141357422]
# 6   [6.769769191741943, 3.2892050743103027, 7.405467987060547, 7.608370304107666, 8.856298446655273, 3.8895153999328613, 0.17763715982437134, 8.51385498046875, -0.4921194314956665, 14.535955429077148]
# 7   [8.332815170288086, 9.459389686584473, 2.354379892349243, 11.285989761352539, 3.7164382934570312, 1.1837884187698364, 1.4744195938110352, 6.738093852996826, 2.795396089553833, 0.20117609202861786]
# 8    [7.294715881347656, 1.0873725414276123, 7.941929340362549, 4.924047946929932, 5.580871105194092, -1.680103063583374, 2.9003400802612305, 6.285297870635986, -2.1978495121002197, 4.077579498291016]
# 9     [8.553359985351562, 7.7629523277282715, 4.443340301513672, 8.728897094726562, 7.046304225921631, 2.980679988861084, 3.743736982345581, 2.4642460346221924, -1.2671756744384766, 5.511058330535889]
# 10   [7.811501502990723, 0.5077887177467346, 7.516637802124023, 5.178676128387451, 5.884215354919434, -2.262202739715576, 2.8085410594940186, 5.12185001373291, -1.8301433324813843, 2.5511865615844727]
# 11     [7.410926342010498, 4.12442684173584, 7.076735019683838, 9.889517784118652, 6.062816619873047, -0.6710233688354492, 11.930248260498047, 8.507768630981445, 6.457851409912109, 1.3432039022445679]
# 12    [7.5907416343688965, 4.754586696624756, 7.123760223388672, 14.004745483398438, 5.9359846115112305, 2.052006959915161, 3.0283639430999756, 2.601377248764038, 1.986826777458191, 6.489041805267334]
#
#    Predicted  \
# 0          C
# 1          C
# 2          C
# 3          C
# 4          C
# 5          C
# 6          H
# 7          I
# 8          I
# 9          I
# 10         G
# 11         J
# 12         S
#
#                                                                           Category_1_descr  \
# 0   WHOLESALE AND RETAIL TRADE SERVICES; REPAIR SERVICES OF MOTOR VEHICLES AND MOTORCYCLES
# 1                                            PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 2                                            PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 3                        WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION SERVICES
# 4                        WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION SERVICES
# 5                        WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION SERVICES
# 6                                          PROFESSIONAL, SCIENTIFIC AND TECHNICAL SERVICES
# 7                                              ARTS, ENTERTAINMENT AND RECREATION SERVICES
# 8                                                                       EDUCATION SERVICES
# 9                                                      ADMINISTRATIVE AND SUPPORT SERVICES
# 10                                                     ADMINISTRATIVE AND SUPPORT SERVICES
# 11                                                     ADMINISTRATIVE AND SUPPORT SERVICES
# 12                                                     TRANSPORTATION AND STORAGE SERVICES
#
#                                                                         Prediced_Cat_descr
# 0                                                                    MANUFACTURED PRODUCTS
# 1                                                                    MANUFACTURED PRODUCTS
# 2                                                                    MANUFACTURED PRODUCTS
# 3                                                                    MANUFACTURED PRODUCTS
# 4                                                                    MANUFACTURED PRODUCTS
# 5                                                                    MANUFACTURED PRODUCTS
# 6                                                      TRANSPORTATION AND STORAGE SERVICES
# 7                                                          ACCOMMODATION AND FOOD SERVICES
# 8                                                          ACCOMMODATION AND FOOD SERVICES
# 9                                                          ACCOMMODATION AND FOOD SERVICES
# 10  WHOLESALE AND RETAIL TRADE SERVICES; REPAIR SERVICES OF MOTOR VEHICLES AND MOTORCYCLES
# 11                                                  INFORMATION AND COMMUNICATION SERVICES
# 12                                                                          OTHER SERVICES

# %%
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           A       1.00      0.97      1.00      0.99      0.99      0.97        76
#           B       1.00      1.00      1.00      1.00      1.00      1.00        17
#           C       0.99      1.00      0.99      0.99      0.99      0.99       577
#           D       1.00      1.00      1.00      1.00      1.00      1.00         4
#           E       1.00      0.86      1.00      0.93      0.93      0.85        22
#           F       1.00      1.00      1.00      1.00      1.00      1.00        28
#           G       0.99      0.99      1.00      0.99      0.99      0.98        76
#           H       0.97      0.97      1.00      0.97      0.98      0.96        30
#           I       0.81      1.00      1.00      0.90      1.00      1.00        13
#           J       0.98      1.00      1.00      0.99      1.00      1.00        64
#           K       1.00      1.00      1.00      1.00      1.00      1.00        26
#           L       1.00      1.00      1.00      1.00      1.00      1.00         9
#           M       1.00      0.97      1.00      0.99      0.99      0.97        39
#           N       1.00      0.92      1.00      0.96      0.96      0.91        37
#           O       1.00      1.00      1.00      1.00      1.00      1.00        10
#           P       1.00      0.91      1.00      0.95      0.95      0.90        11
#           Q       1.00      1.00      1.00      1.00      1.00      1.00        13
#           R       1.00      0.94      1.00      0.97      0.97      0.93        16
#           S       0.92      1.00      1.00      0.96      1.00      1.00        11
#           T       1.00      1.00      1.00      1.00      1.00      1.00         3
#           U       1.00      1.00      1.00      1.00      1.00      1.00         1
#
# avg / total       0.99      0.99      0.99      0.99      0.99      0.98      1083

# %%
CN = text_processing.fetch_CN_files()
Cat1_Cat2_map = CPA[CPA.Level==2][['Code','Parent']].rename(columns={'Code':'Category_2','Parent':'Category_1'})
CN=CN.merge(Cat1_Cat2_map, on='Category_2', how='left')
CN.sample(3)
# Out:
# 2020-11-28 11:51:29,008 - text_processing - INFO - CN new Files imported and cleaned
#         CN_Code  CPA_Code  CN_Section  CN_Level  \
# 3525   22089048  11.01.10  2208 90 48        10
# 12179  81121900  24.45.30  8112 19 00        10
# 960     3061500  10.20.31     0306 15         7
#
#                                            Excl_removed  \
# 3525   (excl. plum, pear or cherry spirit and Calvados)
# 12179
# 960                                          not, incl.
#
#                                                                                                                             CN_Description_cleaned  \
# 3525                                                                                   Spirits distilled from fruit, in containers holding <= 2 l
# 12179                                                                                                                Articles of beryllium, n.e.s.
# 960    Frozen Norway lobsters "Nephrops norvegicus", even smoked, whether in shell or lobsters in shell, cooked by steaming or by boiling in water
#
#       Category_2 Category_1
# 3525          11          C
# 12179         24          C
# 960           10          C

# %%
CN["Descr_cleaned_vectorized"] = CN.CN_Description_cleaned.apply(
    text_to_vec
)

CN["Descr_cleaned_vectorized_low_dimension"] = text_processing.train_predict_umap(
    train_set.Descr_cleaned_vectorized, train_set.Cat, CN.Descr_cleaned_vectorized)

#CN["Descr_cleaned_vectorized_low_dimension"] = text_processing.reduce_dimensionality(CN.Descr_cleaned_vectorized)
# Out:
# 2020-11-28 11:51:37,053 - text_processing - INFO - Now applying umap to reduce dimension
# UMAP(min_dist=0.0, n_components=10, n_neighbors=10, random_state=3052528580,
#      verbose=10)
# Construct fuzzy simplicial set
# Sat Nov 28 11:51:37 2020 Finding Nearest Neighbors
# Sat Nov 28 11:51:37 2020 Building RP forest with 8 trees
# Sat Nov 28 11:51:37 2020 NN descent for 12 iterations
# 	 0  /  12
# 	 1  /  12
# 	 2  /  12
# 	 3  /  12
# 	 4  /  12
# 	 5  /  12
# 	 6  /  12
# 	 7  /  12
# 	 8  /  12
# 	 9  /  12
# 	 10  /  12
# Sat Nov 28 11:51:38 2020 Finished Nearest Neighbor Search
# Sat Nov 28 11:51:38 2020 Construct embedding
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   return f(**kwargs)
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Sat Nov 28 11:51:55 2020 Finished embedding
# 	completed  0  /  30 epochs
# 	completed  3  /  30 epochs
# 	completed  6  /  30 epochs
# 	completed  9  /  30 epochs
# 	completed  12  /  30 epochs
# 	completed  15  /  30 epochs
# 	completed  18  /  30 epochs
# 	completed  21  /  30 epochs
# 	completed  24  /  30 epochs
# 	completed  27  /  30 epochs

# %%
CN_test_df = CN[(CN.Category_2.notnull()) & (CN.CN_Level==4)].drop('Descr_cleaned_vectorized',axis=1)
CN_test_df.sample(2)
# Out:
#         CN_Code  CPA_Code CN_Section  CN_Level       Excl_removed  \
# 3871   26060000  07.29.13       2606         4
# 16076  96040000  32.99.59       9604         4  (excl. colanders)
#
#                 CN_Description_cleaned Category_2 Category_1  \
# 3871   Aluminium ores and concentrates         07          B
# 16076    Hand sieves and hand riddles          32          C
#
#                                                                                                                                                                    Descr_cleaned_vectorized_low_dimension
# 3871   [8.240448951721191, 2.0107781887054443, 5.125513076782227, 5.907821178436279, 2.265899419784546, 2.5733845233917236, 3.3762409687042236, 4.822386264801025, 10.639365196228027, 8.414626121520996]
# 16076  [7.108671188354492, 3.5362138748168945, 3.530350685119629, 2.4551899433135986, -1.039952039718628, 2.3784725666046143, 5.537814617156982, 6.386504173278809, 8.047422409057617, 7.520852088928223]

# %%
CN_test_df = CN[(CN.Category_2.notnull()) & (CN.CN_Level==4)].drop('Descr_cleaned_vectorized',axis=1)
CN_test = np.array(list(CN_test_df["Descr_cleaned_vectorized_low_dimension"].values))
#y_test = np.array(list(test_set.Cat.values))
y_CN_pred=clf.predict(CN_test)

#Import scikit-learn metrics module for accuracy calculation
y_CN_test = np.array(list(CN_test_df.Category_1))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_CN_test, y_CN_pred))

CN_test_df['Predicted'] = pd.Series(data=y_CN_pred.tolist(), index=CN_test_df.index)
#CN_test_df.sample(10)
# Out:
# Accuracy: 0.7348066298342542

# %%
print(classification_report_imbalanced(y_CN_test, y_CN_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           A       0.00      0.00      1.00      0.00      0.00      0.00         9
#           B       0.00      0.00      0.99      0.00      0.00      0.00        18
#           C       0.75      0.99      0.04      0.85      0.21      0.05       134
#           D       0.00      0.00      1.00      0.00      0.00      0.00         2
#           E       0.00      0.00      1.00      0.00      0.00      0.00         7
#           J       0.00      0.00      0.99      0.00      0.00      0.00         4
#           M       0.00      0.00      1.00      0.00      0.00      0.00         1
#           R       0.00      0.00      1.00      0.00      0.00      0.00         5
#           S       0.00      0.00      1.00      0.00      0.00      0.00         1
#
# avg / total       0.55      0.73      0.29      0.63      0.15      0.03       181
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
non_matches = CN_test_df[CN_test_df.Predicted != CN_test_df.Category_1].merge(Cat_descr.rename(columns={'Category_1':'Predicted',
             'Category_1_descr':'Predicted_descr'}),  on='Predicted',how='left').merge(Cat_descr, on='Category_1', how='left')
non_matches.sample(5)
# Out:
#      CN_Code  CPA_Code CN_Section  CN_Level  \
# 9   25020000  08.91.12       2502         4
# 0    4090000  01.49.21       0409         4
# 45  97040000  91.02.20       9704         4
# 30  40040000  38.11.54       4004         4
# 12  25140000  08.11.40       2514         4
#
#                                                                                                          Excl_removed  \
# 9
# 0
# 45                              not of current or new issue in which they have, or will have, a recognised face value
# 30
# 12  not roughly trimmed or merely cut, by sawing or otherwise, into blocks or slabs of a square or rectangular shape;
#
#                                                                                                               CN_Description_cleaned  \
# 9                                                                                                             Unroasted iron pyrites
# 0                                                                                                                      Natural honey
# 45  Postage or revenue stamps, stamp-postmarks, first-day covers, postal stationery, stamped paper and the like, used, or if unused,
# 30                                               Waste, parings and scrap of soft rubber and powders and granules obtained therefrom
# 12                                                                                  Slate, whether or  slate powder and slate refuse
#
#    Category_2 Category_1  \
# 9          08          B
# 0          01          A
# 45         91          R
# 30         38          E
# 12         08          B
#
#                                                                                                                                                                 Descr_cleaned_vectorized_low_dimension  \
# 9   [7.336482048034668, 2.7513153553009033, 4.382230758666992, 3.5765457153320312, 0.6826784610748291, 2.194370985031128, 4.7237324714660645, 5.172999858856201, 8.621283531188965, 8.172290802001953]
# 0      [6.966550827026367, 1.889949917793274, 3.576120376586914, 3.171947717666626, -0.8104632496833801, 3.893202066421509, 4.78844690322876, 4.473344802856445, 5.786776542663574, 7.159286975860596]
# 45  [7.155947208404541, 3.4886226654052734, 3.5725913047790527, 2.449514150619507, -1.0812259912490845, 2.385221481323242, 5.542203903198242, 6.507355213165283, 8.090235710144043, 7.561448097229004]
# 30    [6.818662643432617, 3.144841194152832, 3.7023751735687256, 2.318312168121338, -1.0802149772644043, 2.228505849838257, 5.515503883361816, 5.83602237701416, 7.630491733551025, 7.534660339355469]
# 12        [7.017999649047852, 3.441309928894043, 3.61346435546875, 2.462878704071045, -1.026330590248108, 2.34023118019104, 5.553254127502441, 6.253854751586914, 7.96026611328125, 7.518208980560303]
#
#    Predicted        Predicted_descr  \
# 9          C  MANUFACTURED PRODUCTS
# 0          C  MANUFACTURED PRODUCTS
# 45         C  MANUFACTURED PRODUCTS
# 30         C  MANUFACTURED PRODUCTS
# 12         C  MANUFACTURED PRODUCTS
#
#                                                      Category_1_descr
# 9                                                MINING AND QUARRYING
# 0                       PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 45                        ARTS, ENTERTAINMENT AND RECREATION SERVICES
# 30  WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND REMEDIATION SERVICES
# 12                                               MINING AND QUARRYING

# %%
### repeat the above on level 7

CN_test_df = CN[(CN.Category_2.notnull()) & (CN.CN_Level==7)].drop('Descr_cleaned_vectorized',axis=1)
CN_test = np.array(list(CN_test_df["Descr_cleaned_vectorized_low_dimension"].values))
#y_test = np.array(list(test_set.Cat.values))
y_CN_pred=clf.predict(CN_test)

#Import scikit-learn metrics module for accuracy calculation
y_CN_test = np.array(list(CN_test_df.Category_1))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_CN_test, y_CN_pred))

CN_test_df['Predicted'] = pd.Series(data=y_CN_pred.tolist(), index=CN_test_df.index)
# Out:
# Accuracy: 0.869745575221239

# %%
### repeat the above on level 10

CN_test_df = CN[(CN.Category_2.notnull()) & (CN.CN_Level==10)].drop('Descr_cleaned_vectorized',axis=1)
CN_test = np.array(list(CN_test_df["Descr_cleaned_vectorized_low_dimension"].values))
#y_test = np.array(list(test_set.Cat.values))
y_CN_pred=clf.predict(CN_test)

#Import scikit-learn metrics module for accuracy calculation
y_CN_test = np.array(list(CN_test_df.Category_1))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_CN_test, y_CN_pred))

CN_test_df['Predicted'] = pd.Series(data=y_CN_pred.tolist(), index=CN_test_df.index)
# Out:
# Accuracy: 0.8868203934842395

# %%
### repeat the above on all levels

CN_test_df = CN[(CN.Category_2.notnull())].drop('Descr_cleaned_vectorized',axis=1)
CN_test = np.array(list(CN_test_df["Descr_cleaned_vectorized_low_dimension"].values))
#y_test = np.array(list(test_set.Cat.values))
y_CN_pred=clf.predict(CN_test)

#Import scikit-learn metrics module for accuracy calculation
y_CN_test = np.array(list(CN_test_df.Category_1))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_CN_test, y_CN_pred))

CN_test_df['Predicted'] = pd.Series(data=y_CN_pred.tolist(), index=CN_test_df.index)
# Out:
# Accuracy: 0.8800845219228738
