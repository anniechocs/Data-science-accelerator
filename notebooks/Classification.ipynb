# %% [markdown]
# # TF-IDF Example from scikit-learn docs
#
# Adapted from:
#
# https://scikit-learn.org/stable/auto_examples/model_selection/grid_search_text_feature_extraction.html#sphx-glr-auto-examples-model-selection-grid-search-text-feature-extraction-py

# %%
# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Peter Prettenhofer <peter.prettenhofer@gmail.com>
#         Mathieu Blondel <mathieu@mblondel.org>
# License: BSD 3 clause
from pprint import pprint
from time import time
import logging
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
print(__doc__)

# Display progress logs on stdout
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')
# Out:
# Automatically created module for IPython interactive environment

# %%
# Dimension reduction and clustering libraries
import umap
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score

# %%
CPA = pd.read_csv("../data/processed/CPA_tokenized.csv")
CPA.drop('Unnamed: 0', axis=1, inplace=True)
CPA.head()
# Out:
#      Order  Level     Code Parent  \
# 0  1208792      1        A    NaN
# 1  1208793      2       01      A
# 2  1208794      3     01.1     01
# 3  1208795      4    01.11   01.1
# 4  1208796      5  01.11.1  01.11
#
#                                                Descr  \
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3           Cereals , leguminous crops and oil seeds
# 4                                              Wheat
#
#                                           tokens
# 0   PRODUCTS OF AGRICULTURE FORESTRY AND FISHING
# 1  Products agriculture hunting related services
# 2                            Non-perennial crops
# 3             Cereals leguminous crops oil seeds
# 4                                          Wheat

# %%
# Create categories for Level 1 and Level 2 higherarchies
CPA2 = CPA.copy()
#get highest level of code
CPA2.loc[CPA2.Level !=1,'Category_2'] = CPA2[CPA2.Level !=1].Code.str.split('.').str.slice(0,1).str.join('')

# match up codes and parents
Code_parent = CPA2[CPA2.Level==2][['Parent','Category_2']].copy()
CPA2 = CPA2.merge(Code_parent.rename(columns={'Parent':'Category_1'}), on='Category_2', how='left')

# add in the Category_1 fileds for Level1
CPA2.loc[CPA2.Level==1, 'Category_1'] = CPA2.loc[CPA2.Level==1,'Code']

# we now set up a higher level for A10 indstry levels (10 categories)
update_dict0 = {'A':1,'F':3,'J':5, 'K':6, 'L':7,'M':8,'N':8}
update_dict = {**update_dict0,**dict.fromkeys(['B','C','D','E'],2),**dict.fromkeys(['G','H','I'],4),
               **dict.fromkeys(['O','P','Q'],9), **dict.fromkeys(['R','S','T','U'],10)}

CPA2['Category_0'] = CPA2.Category_1.replace(update_dict)
#CPA2 = CPA2.astype({'Category_0':int})
CPA2.head()
# Out:
# 2020-11-05 15:22:49,976 INFO NumExpr defaulting to 4 threads.
#      Order  Level     Code Parent  \
# 0  1208792      1        A    NaN
# 1  1208793      2       01      A
# 2  1208794      3     01.1     01
# 3  1208795      4    01.11   01.1
# 4  1208796      5  01.11.1  01.11
#
#                                                Descr  \
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3           Cereals , leguminous crops and oil seeds
# 4                                              Wheat
#
#                                           tokens Category_2 Category_1  \
# 0   PRODUCTS OF AGRICULTURE FORESTRY AND FISHING        NaN          A
# 1  Products agriculture hunting related services         01          A
# 2                            Non-perennial crops         01          A
# 3             Cereals leguminous crops oil seeds         01          A
# 4                                          Wheat         01          A
#
#    Category_0
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
# We now create an example based on Level 6 data
CPA_L6 = CPA2[CPA2.Level==6]
CPA_L6.head()
# Out:
#       Order  Level      Code   Parent        Descr       tokens Category_2  \
# 5   1208797      6  01.11.11  01.11.1  Durum wheat  Durum wheat         01
# 6   1208798      6  01.11.12  01.11.1        Wheat        Wheat         01
# 8   1208800      6  01.11.20  01.11.2        Maize        Maize         01
# 10  1208802      6  01.11.31  01.11.3       Barley       Barley         01
# 11  1208803      6  01.11.32  01.11.3          Rye          Rye         01
#
#    Category_1  Category_0
# 5           A           1
# 6           A           1
# 8           A           1
# 10          A           1
# 11          A           1

# %% [markdown]
# ## Notes on using TFIDF
# CountVectorizer implements both tokenization and occurrence counting in a single class
#
# In order to re-weight the count features into floating point values suitable for usage by a classifier it is very common to use the tf–idf transform.
#
# As tf–idf is very often used for text features, there is also another class called TfidfVectorizer that combines all the options of CountVectorizer and TfidfTransformer in a single model
#
# See also [scikit-learn on clustering](https://scikit-learn.org/stable/auto_examples/text/plot_document_clustering.html#sphx-glr-auto-examples-text-plot-document-clustering-py)

# %%
# now reapeat using the ngram character vectorizer
char_ngram_vectorizer = CountVectorizer(analyzer='char', ngram_range=(5, 5))
X3 = char_ngram_vectorizer.fit_transform(CPA_L6.tokens)

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
char_ngram_vectorizer.get_feature_names()[160:240]
# Out:
# [' bags', ' bake', ' baki', ' bala', ' bale', ' ball', ' bals', ' bamb', ' band', ' bank', ' barb', ' baro', ' bars', ' base', ' basi', ' bask', ' bast', ' bath', ' batt', ' bayo', ' beac', ' bead', ' beam', ' bean', ' bear', ' beau', ' bed ', ' bedr', ' beds', ' bee-', ' beer', ' beet', ' bein', ' belt', ' bend', ' bene', ' bent', ' berr', ' bert', ' beta', ' bett', ' beve', ' bib ', ' bicy', ' bide', ' bifu', ' bill', ' bind', ' bing', ' bino', ' bioh', ' biol', ' biot', ' bird', ' bisc', ' bitu', ' blac', ' blad', ' blan', ' blas', ' blaz', ' blin', ' bloc', ' bloo', ' blou', ' blow', ' boar', ' boat', ' bobb', ' bodi', ' bodk', ' body', ' boil', ' bold', ' bolt', ' bond', ' bone', ' book', ' boot', ' bora']

# %%
tfidf_pipeline1 = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
])
tfidf_pipeline2 = Pipeline([
    ('char_vect', char_ngram_vectorizer),
    ('tfidf', TfidfTransformer()),
])

# %%
tfidf_pipeline1.fit(CPA_L6.tokens)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer())])

# %%
tfidf_pipeline2.fit(CPA_L6.tokens)
# Out:
# Pipeline(steps=[('char_vect',
#                  CountVectorizer(analyzer='char', ngram_range=(5, 5))),
#                 ('tfidf', TfidfTransformer())])

# %% [markdown]
# # Simple visualisation - PCA

# %% [markdown]
# Adapted from
#
# https://scikit-learn.org/stable/auto_examples/decomposition/plot_pca_vs_lda.html#sphx-glr-auto-examples-decomposition-plot-pca-vs-lda-py

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.decomposition import PCA

X = tfidf_pipeline2.transform(CPA_L6.tokens).todense()
y = CPA_L6.Category_1
#target_names = ''

pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# plt.show()

# %%
df = CPA_L6.copy()
df['PCA_X'] = X_r[:,0]
df['PCA_Y'] = X_r[:,1]
df.head()
# Out:
#       Order  Level      Code   Parent        Descr       tokens Category_2  \
# 5   1208797      6  01.11.11  01.11.1  Durum wheat  Durum wheat         01
# 6   1208798      6  01.11.12  01.11.1        Wheat        Wheat         01
# 8   1208800      6  01.11.20  01.11.2        Maize        Maize         01
# 10  1208802      6  01.11.31  01.11.3       Barley       Barley         01
# 11  1208803      6  01.11.32  01.11.3          Rye          Rye         01
#
#    Category_1  Category_0     PCA_X     PCA_Y
# 5           A           1 -0.034505 -0.055988
# 6           A           1 -0.034628 -0.056391
# 8           A           1 -0.034390 -0.055593
# 10          A           1 -0.034188 -0.054953
# 11          A           1 -0.033753 -0.053562

# %%
my_palette = sns.color_palette("hls", 10)
plt.figure(figsize=(10,10))
sns.scatterplot(data=df,x='PCA_X', y='PCA_Y', hue='Category_0', palette=my_palette)
# Out:
# <AxesSubplot:xlabel='PCA_X', ylabel='PCA_Y'>

# %% [markdown]
# # T-SNE visualisation
#
# Adapted from: https://www.kaggle.com/premvardhan/amazon-fine-food-review-tsne-visualization
#
# Not so good above 4 dimensions

# %%
from sklearn.manifold import TSNE


X = tfidf_pipeline2.transform(CPA_L6.tokens).todense()
y = CPA_L6.Category_1


pca = PCA(n_components=10)
X_r = pca.fit(X).transform(X)

model = TSNE(n_components=2, random_state=0, perplexity=50, n_iter=5000, verbose=10)

tsne_data = model.fit_transform(X_r)

tsne_df = pd.DataFrame(data=tsne_data, columns=("dim1", "dim2"))
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 3218 samples in 0.005s...
# [t-SNE] Computed neighbors for 3218 samples in 0.334s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3218
# [t-SNE] Computed conditional probabilities for sample 2000 / 3218
# [t-SNE] Computed conditional probabilities for sample 3000 / 3218
# [t-SNE] Computed conditional probabilities for sample 3218 / 3218
# [t-SNE] Mean sigma: 0.006989
# [t-SNE] Computed conditional probabilities in 0.405s
# [t-SNE] Iteration 50: error = 71.6006165, gradient norm = 0.0729834 (50 iterations in 1.098s)
# [t-SNE] Iteration 100: error = 64.3959198, gradient norm = 0.0100198 (50 iterations in 0.846s)
# [t-SNE] Iteration 150: error = 63.6004066, gradient norm = 0.0058067 (50 iterations in 0.850s)
# [t-SNE] Iteration 200: error = 63.2918243, gradient norm = 0.0031348 (50 iterations in 0.872s)
# [t-SNE] Iteration 250: error = 63.1334457, gradient norm = 0.0027715 (50 iterations in 0.884s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.133446
# [t-SNE] Iteration 300: error = 1.0662062, gradient norm = 0.0010105 (50 iterations in 0.857s)
# [t-SNE] Iteration 350: error = 0.8296992, gradient norm = 0.0003478 (50 iterations in 0.858s)
# [t-SNE] Iteration 400: error = 0.7517375, gradient norm = 0.0001968 (50 iterations in 0.815s)
# [t-SNE] Iteration 450: error = 0.7158440, gradient norm = 0.0002001 (50 iterations in 0.812s)
# [t-SNE] Iteration 500: error = 0.6983786, gradient norm = 0.0001201 (50 iterations in 0.823s)
# [t-SNE] Iteration 550: error = 0.6891746, gradient norm = 0.0001136 (50 iterations in 0.808s)
# [t-SNE] Iteration 600: error = 0.6834720, gradient norm = 0.0000970 (50 iterations in 0.810s)
# [t-SNE] Iteration 650: error = 0.6791668, gradient norm = 0.0000865 (50 iterations in 0.809s)
# [t-SNE] Iteration 700: error = 0.6757283, gradient norm = 0.0000847 (50 iterations in 0.795s)
# [t-SNE] Iteration 750: error = 0.6732861, gradient norm = 0.0000757 (50 iterations in 0.819s)
# [t-SNE] Iteration 800: error = 0.6714443, gradient norm = 0.0000702 (50 iterations in 0.789s)
# [t-SNE] Iteration 850: error = 0.6696994, gradient norm = 0.0000686 (50 iterations in 0.807s)
# [t-SNE] Iteration 900: error = 0.6680833, gradient norm = 0.0000659 (50 iterations in 0.790s)
# [t-SNE] Iteration 950: error = 0.6669716, gradient norm = 0.0000577 (50 iterations in 0.792s)
# [t-SNE] Iteration 1000: error = 0.6658031, gradient norm = 0.0000580 (50 iterations in 0.819s)
# [t-SNE] Iteration 1050: error = 0.6647171, gradient norm = 0.0000573 (50 iterations in 0.806s)
# [t-SNE] Iteration 1100: error = 0.6636137, gradient norm = 0.0000559 (50 iterations in 0.820s)
# [t-SNE] Iteration 1150: error = 0.6626626, gradient norm = 0.0000535 (50 iterations in 0.825s)
# [t-SNE] Iteration 1200: error = 0.6619641, gradient norm = 0.0000584 (50 iterations in 0.813s)
# [t-SNE] Iteration 1250: error = 0.6612644, gradient norm = 0.0000581 (50 iterations in 0.834s)
# [t-SNE] Iteration 1300: error = 0.6607393, gradient norm = 0.0000530 (50 iterations in 0.815s)
# [t-SNE] Iteration 1350: error = 0.6602741, gradient norm = 0.0000558 (50 iterations in 0.834s)
# [t-SNE] Iteration 1400: error = 0.6597111, gradient norm = 0.0000506 (50 iterations in 0.822s)
# [t-SNE] Iteration 1450: error = 0.6591675, gradient norm = 0.0000488 (50 iterations in 0.828s)
# [t-SNE] Iteration 1500: error = 0.6585785, gradient norm = 0.0000504 (50 iterations in 0.828s)
# [t-SNE] Iteration 1550: error = 0.6579418, gradient norm = 0.0000499 (50 iterations in 0.800s)
# [t-SNE] Iteration 1600: error = 0.6574258, gradient norm = 0.0000481 (50 iterations in 0.833s)
# [t-SNE] Iteration 1650: error = 0.6569916, gradient norm = 0.0000441 (50 iterations in 0.806s)
# [t-SNE] Iteration 1700: error = 0.6564670, gradient norm = 0.0000508 (50 iterations in 0.805s)
# [t-SNE] Iteration 1750: error = 0.6560575, gradient norm = 0.0000451 (50 iterations in 0.824s)
# [t-SNE] Iteration 1800: error = 0.6557373, gradient norm = 0.0000419 (50 iterations in 0.803s)
# [t-SNE] Iteration 1850: error = 0.6555063, gradient norm = 0.0000463 (50 iterations in 0.826s)
# [t-SNE] Iteration 1900: error = 0.6553072, gradient norm = 0.0000505 (50 iterations in 0.805s)
# [t-SNE] Iteration 1950: error = 0.6550192, gradient norm = 0.0000481 (50 iterations in 0.805s)
# [t-SNE] Iteration 2000: error = 0.6547945, gradient norm = 0.0000429 (50 iterations in 0.828s)
# [t-SNE] Iteration 2050: error = 0.6545993, gradient norm = 0.0000401 (50 iterations in 0.802s)
# [t-SNE] Iteration 2100: error = 0.6543958, gradient norm = 0.0000412 (50 iterations in 0.827s)
# [t-SNE] Iteration 2150: error = 0.6540195, gradient norm = 0.0000408 (50 iterations in 0.807s)
# [t-SNE] Iteration 2200: error = 0.6537536, gradient norm = 0.0000412 (50 iterations in 0.804s)
# [t-SNE] Iteration 2250: error = 0.6534074, gradient norm = 0.0000375 (50 iterations in 0.827s)
# [t-SNE] Iteration 2300: error = 0.6532370, gradient norm = 0.0000435 (50 iterations in 0.807s)
# [t-SNE] Iteration 2350: error = 0.6529943, gradient norm = 0.0000413 (50 iterations in 0.847s)
# [t-SNE] Iteration 2400: error = 0.6527278, gradient norm = 0.0000437 (50 iterations in 0.808s)
# [t-SNE] Iteration 2450: error = 0.6525168, gradient norm = 0.0000428 (50 iterations in 0.815s)
# [t-SNE] Iteration 2500: error = 0.6524119, gradient norm = 0.0000375 (50 iterations in 0.827s)
# [t-SNE] Iteration 2550: error = 0.6521946, gradient norm = 0.0000411 (50 iterations in 0.811s)
# [t-SNE] Iteration 2600: error = 0.6519765, gradient norm = 0.0000384 (50 iterations in 0.832s)
# [t-SNE] Iteration 2650: error = 0.6518315, gradient norm = 0.0000457 (50 iterations in 0.806s)
# [t-SNE] Iteration 2700: error = 0.6517729, gradient norm = 0.0000406 (50 iterations in 0.813s)
# [t-SNE] Iteration 2750: error = 0.6517086, gradient norm = 0.0000369 (50 iterations in 0.824s)
# [t-SNE] Iteration 2800: error = 0.6515059, gradient norm = 0.0000383 (50 iterations in 0.804s)
# [t-SNE] Iteration 2850: error = 0.6513072, gradient norm = 0.0000312 (50 iterations in 0.827s)
# [t-SNE] Iteration 2900: error = 0.6511123, gradient norm = 0.0000332 (50 iterations in 0.804s)
# [t-SNE] Iteration 2950: error = 0.6509024, gradient norm = 0.0000408 (50 iterations in 0.810s)
# [t-SNE] Iteration 3000: error = 0.6506046, gradient norm = 0.0000456 (50 iterations in 0.836s)
# [t-SNE] Iteration 3050: error = 0.6504438, gradient norm = 0.0000362 (50 iterations in 0.814s)
# [t-SNE] Iteration 3100: error = 0.6504216, gradient norm = 0.0000382 (50 iterations in 0.837s)
# [t-SNE] Iteration 3150: error = 0.6503235, gradient norm = 0.0000346 (50 iterations in 0.828s)
# [t-SNE] Iteration 3200: error = 0.6502641, gradient norm = 0.0000317 (50 iterations in 0.816s)
# [t-SNE] Iteration 3250: error = 0.6501039, gradient norm = 0.0000339 (50 iterations in 0.840s)
# [t-SNE] Iteration 3300: error = 0.6499913, gradient norm = 0.0000308 (50 iterations in 0.827s)
# [t-SNE] Iteration 3350: error = 0.6498533, gradient norm = 0.0000302 (50 iterations in 0.822s)
# [t-SNE] Iteration 3400: error = 0.6496642, gradient norm = 0.0000350 (50 iterations in 0.808s)
# [t-SNE] Iteration 3450: error = 0.6495913, gradient norm = 0.0000341 (50 iterations in 0.814s)
# [t-SNE] Iteration 3500: error = 0.6495768, gradient norm = 0.0000340 (50 iterations in 0.816s)
# [t-SNE] Iteration 3550: error = 0.6494349, gradient norm = 0.0000341 (50 iterations in 0.802s)
# [t-SNE] Iteration 3600: error = 0.6493188, gradient norm = 0.0000367 (50 iterations in 0.819s)
# [t-SNE] Iteration 3650: error = 0.6491677, gradient norm = 0.0000347 (50 iterations in 0.807s)
# [t-SNE] Iteration 3700: error = 0.6491629, gradient norm = 0.0000383 (50 iterations in 0.804s)
# [t-SNE] Iteration 3750: error = 0.6490194, gradient norm = 0.0000367 (50 iterations in 0.821s)
# [t-SNE] Iteration 3800: error = 0.6489772, gradient norm = 0.0000319 (50 iterations in 0.867s)
# [t-SNE] Iteration 3850: error = 0.6488519, gradient norm = 0.0000361 (50 iterations in 0.829s)
# [t-SNE] Iteration 3900: error = 0.6488136, gradient norm = 0.0000323 (50 iterations in 0.805s)
# [t-SNE] Iteration 3950: error = 0.6486855, gradient norm = 0.0000310 (50 iterations in 0.812s)
# [t-SNE] Iteration 4000: error = 0.6485816, gradient norm = 0.0000306 (50 iterations in 0.823s)
# [t-SNE] Iteration 4050: error = 0.6485181, gradient norm = 0.0000321 (50 iterations in 0.818s)
# [t-SNE] Iteration 4100: error = 0.6484182, gradient norm = 0.0000394 (50 iterations in 0.831s)
# [t-SNE] Iteration 4150: error = 0.6483251, gradient norm = 0.0000401 (50 iterations in 0.809s)
# [t-SNE] Iteration 4200: error = 0.6482555, gradient norm = 0.0000318 (50 iterations in 0.815s)
# [t-SNE] Iteration 4250: error = 0.6481625, gradient norm = 0.0000363 (50 iterations in 0.820s)
# [t-SNE] Iteration 4300: error = 0.6481881, gradient norm = 0.0000323 (50 iterations in 0.816s)
# [t-SNE] Iteration 4350: error = 0.6481969, gradient norm = 0.0000342 (50 iterations in 0.823s)
# [t-SNE] Iteration 4400: error = 0.6481438, gradient norm = 0.0000315 (50 iterations in 0.811s)
# [t-SNE] Iteration 4450: error = 0.6480588, gradient norm = 0.0000336 (50 iterations in 0.810s)
# [t-SNE] Iteration 4500: error = 0.6479918, gradient norm = 0.0000289 (50 iterations in 0.828s)
# [t-SNE] Iteration 4550: error = 0.6479239, gradient norm = 0.0000323 (50 iterations in 0.814s)
# [t-SNE] Iteration 4600: error = 0.6478662, gradient norm = 0.0000308 (50 iterations in 0.821s)
# [t-SNE] Iteration 4650: error = 0.6478388, gradient norm = 0.0000345 (50 iterations in 0.810s)
# [t-SNE] Iteration 4700: error = 0.6477374, gradient norm = 0.0000328 (50 iterations in 0.818s)
# [t-SNE] Iteration 4750: error = 0.6477319, gradient norm = 0.0000296 (50 iterations in 0.836s)
# [t-SNE] Iteration 4800: error = 0.6476541, gradient norm = 0.0000332 (50 iterations in 0.809s)
# [t-SNE] Iteration 4850: error = 0.6475888, gradient norm = 0.0000348 (50 iterations in 0.836s)
# [t-SNE] Iteration 4900: error = 0.6475881, gradient norm = 0.0000323 (50 iterations in 0.818s)
# [t-SNE] Iteration 4950: error = 0.6475502, gradient norm = 0.0000288 (50 iterations in 0.829s)
# [t-SNE] Iteration 5000: error = 0.6474290, gradient norm = 0.0000335 (50 iterations in 0.831s)
# [t-SNE] KL divergence after 5000 iterations: 0.647429

# %%
df2 = CPA_L6.copy()
df2['dim1'] = tsne_data[:,0]
df2['dim2'] = tsne_data[:,1]
df2.head()
# Out:
#       Order  Level      Code   Parent        Descr       tokens Category_2  \
# 5   1208797      6  01.11.11  01.11.1  Durum wheat  Durum wheat         01
# 6   1208798      6  01.11.12  01.11.1        Wheat        Wheat         01
# 8   1208800      6  01.11.20  01.11.2        Maize        Maize         01
# 10  1208802      6  01.11.31  01.11.3       Barley       Barley         01
# 11  1208803      6  01.11.32  01.11.3          Rye          Rye         01
#
#    Category_1  Category_0       dim1      dim2
# 5           A           1 -23.534948  5.381037
# 6           A           1 -24.595856  5.804392
# 8           A           1 -22.541203  4.600173
# 10          A           1 -20.878454  3.622543
# 11          A           1 -19.470961  0.396028

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df2,x='dim1', y='dim2', hue='Category_0',  palette=my_palette)
# Out:
# <AxesSubplot:xlabel='dim1', ylabel='dim2'>

# %%
#sns.FacetGrid(tsne_df, hue="category", size=6, legend=None).map(plt.scatter, 'dim1', 'dim2').add_legend()
sns.FacetGrid(df2, hue="Category_0", height=10).map(plt.scatter, 'dim1', 'dim2').add_legend()
plt.title("T-SNE for TF-IDF");

# %%
import sklearn.metrics.pairwise

# %%
distance_matrix = sklearn.metrics.pairwise.cosine_distances(X)

# %%
plt.set_cmap("viridis")
plt.figure(figsize=(10, 10))
plt.imshow(1-distance_matrix)
plt.colorbar();

# %%
test = distance_matrix.flatten()
sns.displot(test[test<0.9])

# %%
plt.figure(figsize=(10, 10))
sns.displot(distance_matrix.flatten())

# %% [markdown]
# ## Discussion points:
# * Curse of dimensionality
# * Uni-modal pairwise distance distribution
# * Dimensionality reduction
# * Clustering e.g. HDBSCAN

# %% [markdown]
# # Classification

# %%
df2.head()
# Out:
#       Order  Level      Code   Parent        Descr       tokens Category_2  \
# 5   1208797      6  01.11.11  01.11.1  Durum wheat  Durum wheat         01
# 6   1208798      6  01.11.12  01.11.1        Wheat        Wheat         01
# 8   1208800      6  01.11.20  01.11.2        Maize        Maize         01
# 10  1208802      6  01.11.31  01.11.3       Barley       Barley         01
# 11  1208803      6  01.11.32  01.11.3          Rye          Rye         01
#
#    Category_1  Category_0       dim1      dim2
# 5           A           1 -23.534948  5.381037
# 6           A           1 -24.595856  5.804392
# 8           A           1 -22.541203  4.600173
# 10          A           1 -20.878454  3.622543
# 11          A           1 -19.470961  0.396028

# %%
df2['Category_3'] = df2.Category_0==2
df2
# Out:
#         Order  Level      Code   Parent  \
# 5     1208797      6  01.11.11  01.11.1
# 6     1208798      6  01.11.12  01.11.1
# 8     1208800      6  01.11.20  01.11.2
# 10    1208802      6  01.11.31  01.11.3
# 11    1208803      6  01.11.32  01.11.3
# ...       ...    ...       ...      ...
# 5505  1214297      6  97.00.14  97.00.1
# 5506  1214298      6  97.00.19  97.00.1
# 5511  1214303      6  98.10.10  98.10.1
# 5515  1214307      6  98.20.10  98.20.1
# 5521  1214313      6  99.00.10  99.00.1
#
#                                                   Descr  \
# 5                                           Durum wheat
# 6                                                 Wheat
# 8                                                 Maize
# 10                                               Barley
# 11                                                  Rye
# ...                                                 ...
# 5505  Services of households as employers of domesti...
# 5506  Other services of households as employers of d...
# 5511  Undifferentiated goods produced by private hou...
# 5515  Undifferentiated services produced by private ...
# 5521  Services provided by extraterritorial organisa...
#
#                                                  tokens Category_2 Category_1  \
# 5                                           Durum wheat         01          A
# 6                                                 Wheat         01          A
# 8                                                 Maize         01          A
# 10                                               Barley         01          A
# 11                                                  Rye         01          A
# ...                                                 ...        ...        ...
# 5505  Services households employers domestic personn...         97          T
# 5506  Other services households employers domestic p...         97          T
# 5511  Undifferentiated goods produced private househ...         98          T
# 5515  Undifferentiated services produced private hou...         98          T
# 5521  Services provided extraterritorial organisatio...         99          U
#
#       Category_0       dim1       dim2  Category_3
# 5              1 -23.534948   5.381037       False
# 6              1 -24.595856   5.804392       False
# 8              1 -22.541203   4.600173       False
# 10             1 -20.878454   3.622543       False
# 11             1 -19.470961   0.396028       False
# ...          ...        ...        ...         ...
# 5505          10  36.422226 -27.129738       False
# 5506          10  46.691616 -24.176235       False
# 5511          10 -60.842850  -3.695708       False
# 5515          10  42.665653 -21.872417       False
# 5521          10  45.227417 -15.080805       False
#
# [3218 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict

#train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
train_set, test_set = train_test_split(df2, test_size=0.2, random_state=42)
train_set.head()
# Out:
#         Order  Level      Code   Parent  \
# 42    1208834      6  01.11.96  01.11.9
# 4521  1213313      6  64.19.22  64.19.2
# 34    1208826      6  01.11.81  01.11.8
# 2680  1211472      6  28.24.99  28.24.9
# 1707  1210499      6  23.12.11  23.12.1
#
#                                                   Descr  \
# 42                                     Castor oil seeds
# 4521  Consumer credit granting services by monetary ...
# 34                                           Soya beans
# 2680  Sub-contracted operations as part of manufactu...
# 1707  Glass in sheets, bent, edge-worked, engraved, ...
#
#                                                  tokens Category_2 Category_1  \
# 42                                     Castor oil seeds         01          A
# 4521  Consumer credit granting services monetary ins...         64          K
# 34                                           Soya beans         01          A
# 2680  Sub-contracted operations part manufacturing p...         28          C
# 1707  Glass sheets bent edge-worked engraved drilled...         23          C
#
#       Category_0       dim1       dim2  Category_3
# 42             1 -36.595070   3.114781       False
# 4521           6  51.609531 -47.119980       False
# 34             1 -25.492762   5.968357       False
# 2680           2  -9.836273 -78.275368        True
# 1707           2 -44.744255   4.691380        True

# %%
X_train = train_set[['dim1','dim2']]
y_train_BE = train_set.Category_3
forest_clf = RandomForestClassifier(random_state=42)
y_probas_forest = cross_val_predict(forest_clf, X_train, y_train_BE, cv=3,  method="predict_proba")

# %%
y_scores = cross_val_predict(forest_clf, X_train, y_train_BE, cv=3,
                             method='predict_proba')

# %%
y_scores
# Out:
# array([[0.21, 0.79],
#        [0.92, 0.08],
#        [0.12, 0.88],
#        ...,
#        [0.07, 0.93],
#        [0.  , 1.  ],
#        [0.94, 0.06]])

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_train_BE, y_scores[:,1])

# %%
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--') # dashed diagonal
    plt.axis([0, 1, 0, 1])                                    # Not shown in the book
    plt.xlabel('False Positive Rate (Fall-Out)', fontsize=16) # Not shown
    plt.ylabel('True Positive Rate (Recall)', fontsize=16)    # Not shown
    plt.grid(True)                                            # Not shown

plt.figure(figsize=(8, 8))                         # Not shown
plot_roc_curve(fpr, tpr)

#save_fig("roc_curve_plot")                         # Not shown
plt.show()

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_train_BE, y_scores[:,1])
# Out:
# 0.9392807474402411

# %%
df2.Category_3.sum()
# Out:
# 1874

# %%
len(df2)
# Out:
# 3218

# %% [markdown]
# ## UMAP example

# %%
# u-map
# Dimension reduction and clustering libraries
import umap
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score

# %%
sns.set(style='white', rc={'figure.figsize':(10,8)})

# %%
standard_embedding = umap.UMAP(random_state=42).fit_transform(df2.dim1, df2.dim2)
