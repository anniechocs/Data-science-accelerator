# %% [markdown]
# # Text Processing for Accelerator project
#
# A simplified pipeline processing text with FastText.
#
# * Load CPA data
# * Basic text cleaning
# * Vectorize (with FastText)
# * Reduce dimension using UMAP, both supervised and unsupervised
# * Predict unclassified data

# %%
# this bit shouldn't be necessary if we pip install -e .   in the parent directory
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import functools
from pprint import pprint
from time import time
from IPython.display import display, HTML
import logging
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

from sklearn import metrics
import umap

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express

pd.set_option('display.max_colwidth', None)

# %%
import text_processing

# %% [markdown]
# #### Load in the CPA data

# %%
CPA = text_processing.fetch_files()
# Out:
# 2020-11-26 13:02:00,055 - text_processing - INFO - cleanded CPA File imported

# %%
CPA[CPA.Level.isin({2,3,4,5,6})].head(6)
# Out:
#      Order  Level      Code   Parent  \
# 1  1208793      2        01        A
# 2  1208794      3      01.1       01
# 3  1208795      4     01.11     01.1
# 4  1208796      5   01.11.1    01.11
# 5  1208797      6  01.11.11  01.11.1
# 6  1208798      6  01.11.12  01.11.1
#
#                                                Descr_old  \
# 1  Products of agriculture, hunting and related services
# 2                                    Non-perennial crops
# 3  Cereals (except rice), leguminous crops and oil seeds
# 4                                                  Wheat
# 5                                            Durum wheat
# 6                              Wheat, except durum wheat
#
#                                                    Descr  \
# 1  Products of agriculture, hunting and related services
# 2                                    Non-perennial crops
# 3               Cereals , leguminous crops and oil seeds
# 4                                                  Wheat
# 5                                            Durum wheat
# 6                                                  Wheat
#
#                                                                     Includes  \
# 1                                                                        NaN
# 2                                                                        NaN
# 3  cereals, leguminous crops and oil seeds grown for food and other purposes
# 4                                                                        NaN
# 5                                                                        NaN
# 6                                                                        NaN
#
#   Category_2 Category_1  Category_0
# 1         01          A           1
# 2         01          A           1
# 3         01          A           1
# 4         01          A           1
# 5         01          A           1
# 6         01          A           1

# %%
CPA1 = CPA[CPA.Level==6][['Code','Descr_old','Descr','Category_0','Category_1','Category_2']].copy()
df = text_processing.clean_col(CPA1, "Descr")
df.drop('Descr',axis=1,inplace=True)
df.sample(5)
# Out:
# 2020-11-26 17:03:43,339 - text_processing - INFO - Cleaning column: Descr
# 2020-11-26 17:03:43,339 - text_processing - INFO - Cleaning column: Descr
# 2020-11-26 17:03:43,339 - text_processing - INFO - Cleaning column: Descr
# 2020-11-26 17:03:43,339 - text_processing - INFO - Cleaning column: Descr
# 2020-11-26 17:03:43,339 - text_processing - INFO - Cleaning column: Descr
# 2020-11-26 17:03:43,339 - text_processing - INFO - Cleaning column: Descr
# 2020-11-26 17:03:43,339 - text_processing - INFO - Cleaning column: Descr
#           Code  \
# 3980  47.00.67
# 240   01.49.11
# 3666  45.31.12
# 1046  15.11.22
# 2618  28.14.13
#
#                                                                   Descr_old  \
# 3980                                Retail trade services of games and toys
# 240                                                  Domestic rabbits, live
# 3666  Wholesale trade services of other motor vehicle parts and accessories
# 1046        Patent leather and patent laminated leather; metallised leather
# 2618     Process control valves, gate valves, globe valves and other valves
#
#       Category_0 Category_1 Category_2  \
# 3980           4          G         47
# 240            1          A         01
# 3666           4          G         45
# 1046           2          C         15
# 2618           2          C         28
#
#                                                    Descr_cleaned
# 3980                            retail trade services games toys
# 240                                        domestic rabbits live
# 3666    wholesale trade services motor vehicle parts accessories
# 1046  patent leather patent laminated leather metallised leather
# 2618      process control valves gate valves globe valves valves

# %% [markdown]
# ## Load FastText Pretrained
#
# Note: This requires a fair bit of memory (peaks at about 17.5 GiB)
#
# Recommend shutting down other kernels first, once this has loaded memory usage drops again.
#
# This takes a few minutes to load in.

# %%
wv = text_processing.fetch_fasstext_pretrained(filepath="../../data/wiki.en.bin")
# Out:
# 2020-11-26 13:02:11,119 - text_processing - INFO - Loading FastText pretrained from ../../data/wiki.en.bin
# 2020-11-26 13:05:51,347 - text_processing - INFO - Model loaded

# %% [markdown]
# ### Vectorize CPA data using FastText

# %%
text_to_vec = functools.partial(text_processing.vectorize_text, wv)
df["Descr_cleaned_vectorized"] = df.Descr_cleaned.apply(
    text_to_vec
)

# %% [markdown]
# ## Dimensionality Reduction using UMAP

# %% [markdown]
# ### Unsupervised dimension reduction

# %%
# df["Descr_cleaned_vectorized_low_dimension"] = text_processing.reduce_dimensionality(df.Descr_cleaned_vectorized)

# %% [markdown]
# ### Dimensionality Reduction using UMAP supervised

# %%
df['Cat'] = df.Category_2.astype(int)
df["Descr_cleaned_vectorized_low_dimension"] = text_processing.reduce_dimensionality_supervised(df.Descr_cleaned_vectorized, df.Cat)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:16:10,869 - text_processing - INFO - Now applying umap to reduce dimension
# UMAP(min_dist=0.0, n_components=10, n_neighbors=10, random_state=3052528580,
#      verbose=10)
# Construct fuzzy simplicial set
# Thu Nov 26 17:16:16 2020 Finding Nearest Neighbors
# Thu Nov 26 17:16:17 2020 Finished Nearest Neighbor Search
# Thu Nov 26 17:16:17 2020 Construct embedding
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Thu Nov 26 17:16:27 2020 Finished embedding

# %% [markdown]
# # Use the Random Forest Classifier
#
# https://www.datacamp.com/community/tutorials/random-forests-classifier-python
#
# We have already split our data into training and test datasets and used UMAP supervised classification to reduce the dimension on the training set.
# We then used UMAP prediction to reduce the dimension on the test set.
#
# We now use the random forest classifier on the training set, and see how it works on the test set.

# %%
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

X_data = np.array(list(df["Descr_cleaned_vectorized_low_dimension"].values))
y_data = np.array(list(df.Cat.values))

# Split dataset into training set and test set

train_set, test_set = train_test_split(df.copy(), test_size=0.2, random_state=42)

#Train the model using the training sets 
X_train = np.array(list(train_set["Descr_cleaned_vectorized_low_dimension"].values))
y_train = np.array(list(train_set.Cat.values))

X_test = np.array(list(test_set["Descr_cleaned_vectorized_low_dimension"].values))
y_test = np.array(list(test_set.Cat.values))

clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %% [markdown]
# #### Accuracy

# %%
#Import scikit-learn metrics module for accuracy calculation
y_test = np.array(list(test_set.Cat.values))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9440993788819876

# %%
# get a dataframe of the level 2 descriptions
Cat_2_descr = text_processing.get_category_description(CPA, 2)
Cat_2_descr.sample(5)
# Out:
#      Category_2  \
# 307          03
# 4252         58
# 4924         75
# 948          14
# 5043         80
#
#                                                                         Category_2_descr
# 307   Fish and other fishing products; aquaculture products; support services to fishing
# 4252                                                                 Publishing services
# 4924                                                                 Veterinary services
# 948                                                                      Wearing apparel
# 5043                                                 Security and investigation services

# %%
print(len(y_pred), len(y_test))
test_set['Predicted'] = pd.Series(data=y_pred.tolist(), index=test_set.index)
non_matches0 = test_set[test_set.Predicted != test_set.Cat].drop('Descr_cleaned_vectorized',axis=1)
non_matches1 = non_matches0.merge(Cat_2_descr, on='Category_2', how='left')
non_matches = non_matches1.merge(Cat_2_descr.astype({'Category_2':int}).rename(columns={'Category_2_descr':'Prediced_Cat_descr', 'Category_2':'Predicted'}),
                                 on='Predicted', how='left')
# Out:
# 644 644

# %%
non_matches.sample(5)
# Out:
#         Code  \
# 11  25.29.12
# 12  82.91.12
# 4   38.11.53
# 29  49.42.19
# 28  02.30.30
#
#                                                                         Descr_old  \
# 11                           Containers for compressed or liquefied gas, of metal
# 12                                                     Collection agency services
# 4                                                  Used pneumatic tyres of rubber
# 29                                                         Other removal services
# 28  Parts of plants, grasses, mosses and lichens suitable for ornamental purposes
#
#     Category_0 Category_1 Category_2  \
# 11           2          C         25
# 12           8          N         82
# 4            2          E         38
# 29           4          H         49
# 28           1          A         02
#
#                                                        Descr_cleaned  Cat  \
# 11                         containers compressed liquefied gas metal   25
# 12                                        collection agency services   82
# 4                                        used pneumatic tyres rubber   38
# 29                                                  removal services   49
# 28  parts plants grasses mosses lichens suitable ornamental purposes    2
#
#                                                                                                                                                                    Descr_cleaned_vectorized_low_dimension  \
# 11  [-0.8115108609199524, -1.430631399154663, 8.333356857299805, 6.275633335113525, 3.0283453464508057, 10.21987247467041, 6.265014171600342, 11.358818054199219, 6.2893805503845215, 3.3160688877105713]
# 12       [1.7448574304580688, -0.2587381899356842, 9.817572593688965, -1.3335999250411987, 0.1072535365819931, 7.5663743019104, 10.364123344421387, 4.88882303237915, 8.78766918182373, 5.37332010269165]
# 4      [2.125735282897949, 0.18328115344047546, 11.344267845153809, 4.874699115753174, 7.469050407409668, 8.979768753051758, 3.2050251960754395, 9.698098182678223, 7.124595642089844, 5.445359230041504]
# 29  [0.9574466347694397, -0.08783234655857086, 10.253785133361816, -0.6963055729866028, 0.2968844771385193, 7.591365814208984, 8.62102222442627, 4.420943260192871, 9.097941398620605, 4.799103260040283]
# 28     [0.5206250548362732, 1.4218617677688599, 9.28674030303955, 12.447073936462402, 0.7991464734077454, 6.10408353805542, 10.701151847839355, 1.7812113761901855, 9.422142028808594, 7.952404499053955]
#
#     Predicted  \
# 11         27
# 12         74
# 4          22
# 29         37
# 28          1
#
#                                                                   Category_2_descr  \
# 11                       Fabricated metal products, except machinery and equipment
# 12       Office administrative, office support and other business support services
# 4   Waste collection, treatment and disposal services; materials recovery services
# 29                    Land transport services and transport services via pipelines
# 28                              Products of forestry, logging and related services
#
#                                        Prediced_Cat_descr
# 11                                   Electrical equipment
# 12  Other professional, scientific and technical services
# 4                             Rubber and plastic products
# 29                       Sewerage services; sewage sludge
# 28  Products of agriculture, hunting and related services

# %%
CN = text_processing.fetch_CN_files()
CN.sample(3)
# Out:
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
# 2020-11-26 17:21:39,206 - text_processing - INFO - CN new Files imported and cleaned
#         CN_Code  CPA_Code  CN_Section  CN_Level Excl_removed  \
# 12199  81129289  24.45.30  8112 92 89        10
# 6362   38249945  20.59.59  3824 99 45        10
# 2265   12129200  01.25.90     1212 92         7   not ground
#
#                                                   CN_Description_cleaned  \
# 12199                                 Unwrought gallium; gallium powders
# 6362                                  Anti-scaling and similar compounds
# 2265   Locust beans "carob", fresh, chilled, frozen or dried, whether or
#
#       Category_2
# 12199         24
# 6362          20
# 2265          01

# %%
CN["Descr_cleaned_vectorized"] = CN.CN_Description_cleaned.apply(
    text_to_vec
)

CN["Descr_cleaned_vectorized_low_dimension"] = text_processing.train_predict_umap(
    train_set.Descr_cleaned_vectorized, train_set.Cat, CN.Descr_cleaned_vectorized)

#CN["Descr_cleaned_vectorized_low_dimension"] = text_processing.reduce_dimensionality(CN.Descr_cleaned_vectorized)
# Out:
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# 2020-11-26 17:21:48,731 - text_processing - INFO - Now applying umap to reduce dimension
# UMAP(min_dist=0.0, n_components=10, n_neighbors=10, random_state=3052528580,
#      verbose=10)
# Construct fuzzy simplicial set
# Thu Nov 26 17:21:52 2020 Finding Nearest Neighbors
# Thu Nov 26 17:21:52 2020 Finished Nearest Neighbor Search
# Thu Nov 26 17:21:52 2020 Construct embedding
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Thu Nov 26 17:22:00 2020 Finished embedding
# 	completed  0  /  30 epochs
# 	completed  3  /  30 epochs
# 	completed  6  /  30 epochs
# 	completed  9  /  30 epochs
# 	completed  12  /  30 epochs
# 	completed  15  /  30 epochs
# 	completed  18  /  30 epochs
# 	completed  21  /  30 epochs
# 	completed  24  /  30 epochs
# 	completed  27  /  30 epochs

# %%
CN_test_df = CN[(CN.Category_2.notnull()) & (CN.CN_Level==4)].drop('Descr_cleaned_vectorized',axis=1)
CN_test = np.array(list(CN_test_df["Descr_cleaned_vectorized_low_dimension"].values))
#y_test = np.array(list(test_set.Cat.values))
y_CN_pred=clf.predict(CN_test)

#Import scikit-learn metrics module for accuracy calculation
y_CN_test = np.array(list(CN_test_df.Category_2.astype(int)))
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_CN_test, y_CN_pred))

CN_test_df['Predicted'] = pd.Series(data=y_CN_pred.tolist(), index=CN_test_df.index)
CN_test_df.sample(10)
# Out:
# Accuracy: 0.09392265193370165
#         CN_Code  CPA_Code CN_Section  CN_Level  \
# 10403  69060000  23.32.13       6906         4
# 12075  80030000  24.43.24       8003         4
# 6285   38220000  20.59.52       3822         4
# 4118   27150000  23.99.13       2715         4
# 11831  74130000  25.93.12       7413         4
# 3883   26100000  07.29.19       2610         4
# 3867   26050000  07.29.19       2605         4
# 15424  90200000  32.99.59       9020         4
# 10201  65070000  14.19.43       6507         4
# 3880   26090000  07.29.15       2609         4
#
#                                                                                                                                                                                                                                                                                                        Excl_removed  \
# 10403                                                                      (excl. of siliceous fossil meals or similar siliceous earths, refractory ceramic goods, chimney liners, pipes specifically manufactured for laboratories, insulating tubing and fittings and other piping for electrotechnical purposes)
# 12075
# 6285   (excl. compound diagnostic reagents designed to be administered to the patient, blood-grouping reagents, animal blood prepared for therapeutic, prophylactic or diagnostic uses and vaccines, toxins, cultures of micro-organisms and similar products) not on a backing, and certified reference materials
# 4118
# 11831                                                                                                                                                                                                                                                                       (excl. electrically insulated products)
# 3883
# 3867
# 15424                                                                                                                                                       (excl. protective masks having neither mechanical parts nor replaceable filters, and artificial respiration or other therapeutic respiration apparatus)
# 10201                                                                                                                                                                                                                                       (excl. headbands used by sportsmen as sweatbands, knitted or crocheted)
# 3880
#
#                                                                                                                                                        CN_Description_cleaned  \
# 10403                                                                                                                   Ceramic pipes, conduits, guttering and pipe fittings
# 12075                                                                                                                               Tin bars, rods, profiles and wire, n.e.s.
# 6285                                                                    Diagnostic or laboratory reagents on a backing, prepared diagnostic or laboratory reagents whether or
# 4118   Bituminous mastics, cut-backs and other bituminous mixtures based on natural asphalt, on natural bitumen, on petroleum bitumen, on mineral tar or on mineral tar pitch
# 11831                                                                                                           Stranded wire, cables, plaited bands and the like, of copper
# 3883                                                                                                                                           Chromium ores and concentrates
# 3867                                                                                                                                             Cobalt ores and concentrates
# 15424                                                                                                                                     Breathing appliances and gas masks
# 10201                                                                            Headbands, linings, covers, hat foundations, hat frames, peaks and chinstraps, for headgear
# 3880                                                                                                                                                Tin ores and concentrates
#
#       Category_2  \
# 10403         23
# 12075         24
# 6285          20
# 4118          23
# 11831         25
# 3883          07
# 3867          07
# 15424         32
# 10201         14
# 3880          07
#
#                                                                                                                                                                          Descr_cleaned_vectorized_low_dimension  \
# 10403      [-0.8890625834465027, -0.1693418174982071, 2.164217710494995, 7.909590244293213, 1.73959481716156, 3.0076496601104736, 10.418719291687012, 6.70717716217041, 13.447763442993164, 2.4053380489349365]
# 12075     [-0.6886611580848694, 0.06508789211511612, 1.5180352926254272, 8.117136001586914, 2.4776270389556885, 2.8708581924438477, 9.843130111694336, 6.500426292419434, 12.549605369567871, 2.54296612739563]
# 6285   [-0.44529882073402405, 0.13770945370197296, 0.12416297197341919, 8.576146125793457, 4.604890823364258, -0.5970372557640076, 5.340291500091553, 10.21834659576416, 8.548567771911621, 1.8389836549758911]
# 4118           [0.6560388803482056, 0.6665619611740112, 0.8140869736671448, 8.240727424621582, 4.632938385009766, 2.58549427986145, 7.72888708114624, 6.040282726287842, 9.439143180847168, 2.4615745544433594]
# 11831       [-0.2675167918205261, 0.4591939449310303, 0.2964555323123932, 8.457222938537598, 4.491921901702881, 2.7510898113250732, 8.40706729888916, 5.544773578643799, 9.628931999206543, 2.6415717601776123]
# 3883    [-1.4609551429748535, 1.3051457405090332, 2.4970250129699707, 7.5469279289245605, 2.3846802711486816, 1.3388255834579468, 10.09211540222168, 10.378777503967285, 14.378164291381836, 4.065723419189453]
# 3867     [-1.4616997241973877, 1.3068289756774902, 2.4982056617736816, 7.54635763168335, 2.3854737281799316, 1.3362014293670654, 10.089130401611328, 10.381552696228027, 14.376641273498535, 4.067243576049805]
# 15424    [-0.21305778622627258, 0.3645002841949463, -0.03430357575416565, 8.305000305175781, 3.178992748260498, 2.445214033126831, 7.956547737121582, 7.218453884124756, 11.039538383483887, 2.132152557373047]
# 10201     [-0.5008111596107483, 0.6202476620674133, -0.23367127776145935, 8.453653335571289, 4.462147235870361, 2.4784324169158936, 8.892607688903809, 3.99592924118042, 8.160361289978027, 2.6944704055786133]
# 3880      [-0.8000733852386475, 0.4708726406097412, 1.6032538414001465, 7.985667705535889, 2.6121397018432617, 1.9071203470230103, 9.081939697265625, 8.136235237121582, 13.468693733215332, 2.656273603439331]
#
#        Predicted
# 10403          3
# 12075          3
# 6285          13
# 4118          13
# 11831         13
# 3883          26
# 3867          26
# 15424          3
# 10201         13
# 3880           3

# %%
sample = CN_test_df.sample(5)
sample_test = np.array(list(sample["Descr_cleaned_vectorized_low_dimension"].values))
display(sample)
clf.predict(sample_test)
# Out:
#         CN_Code  CPA_Code CN_Section  CN_Level  \
# 8949   56050000  13.96.11       5605         4
# 10733  71090000  24.41.40       7109         4
# 4118   27150000  23.99.13       2715         4
# 6835   40070000  22.19.20       4007         4
# 4571   28470000  20.13.63       2847         4
#
#                                                                                                                                                                                                         Excl_removed  \
# 8949   (excl. yarns manufactured from a mixture of textile fibres and metal fibres, with anti-static properties; yarns reinforced with metal wire; articles with the character of trimmings), whether or not gimped,
# 10733                                                                                                                                                                      not further worked than semi-manufactured
# 4118
# 6835                                                                         (excl. ungimped single thread with a diameter of > 5 mm and textiles combined with rubber thread, e.g. textile-covered thread and cord)
# 4571                                                                                                                                                                                        not solidified with urea
#
#                                                                                                                                                                        CN_Description_cleaned  \
# 8949   Metallised yarn being textile yarn, or strip or the like of heading 5404 or 5405, of textile fibres, combined with metal in the form of thread, strip or powder or covered with metal
# 10733                                                                                                                                                  Base metals or silver, clad with gold,
# 4118                   Bituminous mastics, cut-backs and other bituminous mixtures based on natural asphalt, on natural bitumen, on petroleum bitumen, on mineral tar or on mineral tar pitch
# 6835                                                                                                                                                       Vulcanised rubber thread and cord
# 4571                                                                                                                                                            Hydrogen peroxide, whether or
#
#       Category_2  \
# 8949          13
# 10733         24
# 4118          23
# 6835          22
# 4571          20
#
#                                                                                                                                                                        Descr_cleaned_vectorized_low_dimension  \
# 8949    [-0.33936792612075806, 0.5814311504364014, 0.11199671775102615, 8.453661918640137, 4.514398574829102, 2.82140851020813, 8.336427688598633, 5.3873186111450195, 9.444144248962402, 2.6217498779296875]
# 10733  [-0.5094356536865234, -0.07921215146780014, 1.7569701671600342, 8.27991771697998, 2.158804178237915, 3.015340805053711, 10.629666328430176, 7.156980991363525, 14.166692733764648, 2.7605931758880615]
# 4118         [0.6560388803482056, 0.6665619611740112, 0.8140869736671448, 8.240727424621582, 4.632938385009766, 2.58549427986145, 7.72888708114624, 6.040282726287842, 9.439143180847168, 2.4615745544433594]
# 6835      [-0.9910297393798828, 0.5775982141494751, -0.6554473638534546, 8.50863265991211, 5.113471984863281, 3.0270373821258545, 8.389033317565918, 5.005032539367676, 8.77334976196289, 2.6810030937194824]
# 4571    [-0.9621415734291077, -0.5279266834259033, 0.7720573544502258, 8.87329387664795, 5.897768974304199, -2.553973913192749, 4.925012111663818, 15.024232864379883, 6.830611228942871, 0.5037585496902466]
#
#        Predicted
# 8949          13
# 10733         26
# 4118          13
# 6835          13
# 4571          35
# array([13, 26, 13, 13, 35])

# %%
Cat_2_descr.head(30)
# Out:
#      Category_2  \
# 1            01
# 274          02
# 307          03
# 345          05
# 354          06
# 365          07
# 382          08
# 421          09
# 434          10
# 759          11
# 802          12
# 813          13
# 948          14
# 1039         15
# 1085         16
# 1161         17
# 1245         18
# 1277         19
# 1313         20
# 1581         21
# 1615         22
# 1697         23
# 1870         24
# 2067         25
# 2218         26
# 2401         27
# 2561         28
# 2898         29
# 2962         30
# 3067         31
#
#                                                                                        Category_2_descr
# 1                                                 Products of agriculture, hunting and related services
# 274                                                  Products of forestry, logging and related services
# 307                  Fish and other fishing products; aquaculture products; support services to fishing
# 345                                                                                    Coal and lignite
# 354                                                                     Crude petroleum and natural gas
# 365                                                                                          Metal ores
# 382                                                                 Other mining and quarrying products
# 421                                                                             Mining support services
# 434                                                                                       Food products
# 759                                                                                           Beverages
# 802                                                                                    Tobacco products
# 813                                                                                            Textiles
# 948                                                                                     Wearing apparel
# 1039                                                                       Leather and related products
# 1085  Wood and of products of wood and cork, except furniture; articles of straw and plaiting materials
# 1161                                                                           Paper and paper products
# 1245                                               Printing and reproduction services of recorded media
# 1277                                                                Coke and refined petroleum products
# 1313                                                                    Chemicals and chemical products
# 1581                                      Basic pharmaceutical products and pharmaceutical preparations
# 1615                                                                        Rubber and plastic products
# 1697                                                                Other non-metallic mineral products
# 1870                                                                                       Basic metals
# 2067                                          Fabricated metal products, except machinery and equipment
# 2218                                                          Computer, electronic and optical products
# 2401                                                                               Electrical equipment
# 2561                                                                     Machinery and equipment n.e.c.
# 2898                                                         Motor vehicles, trailers and semi-trailers
# 2962                                                                          Other transport equipment
# 3067                                                                                          Furniture
