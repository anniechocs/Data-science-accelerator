# %%
import pandas as pd
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import nltk
import pickle
import re
import string

from nltk import ngrams
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import punkt
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.stem import wordnet
from nltk.corpus import stopwords

from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors
print('done')
# Out:
# <style>.container { width:100% !important; }</style>
# done

# %%
data_path = '../data/processed/'
# read in CPA data
CPA = pd.read_csv(data_path + "CPA_2_1.csv", skiprows=1, sep=',',                  
                  names=['Order','Level','Code','Parent','Description','Includes','Also','Rulings','Excludes'])
# read in SITC data
SITC = pd.read_csv(data_path+'SITC_Rev3_UN.csv', skiprows=2, names=['Code','Description'])
# Read in CN data file
CN = pd.read_csv(data_path+"CN_2020.csv", header=None, sep=',', names=['Code','Section','Description'])

# read in other codes data
BEC = pd.read_csv(data_path + "BEC_Rev_5.csv", skiprows=1, names=['Code','BEC'], index_col=False)
COICOP = pd.read_csv(data_path+'COICOP_2018.csv')
#PRD = pd.read_csv(data_path+ "PRD_2019.csv")

# read in mapping data
#CN_CPA = pd.read_csv(data_path+'CN 2020-CPA 2.1.csv', skiprows=1)
#CPA_COI = pd.read_csv(data_path + 'COICOP 2018 - CPA 2 1.csv')
SITC
CPA.head()
# Out:
#      Order  Level     Code Parent  \
# 0  1208792      1        A    NaN
# 1  1208793      2       01      A
# 2  1208794      3     01.1     01
# 3  1208795      4    01.11   01.1
# 4  1208796      5  01.11.1  01.11
#
#                                          Description  \
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3  Cereals (except rice), leguminous crops and oi...
# 4                                              Wheat
#
#                                             Includes Also Rulings Excludes
# 0                                                NaN  NaN     NaN      NaN
# 1                                                NaN  NaN     NaN      NaN
# 2                                                NaN  NaN     NaN      NaN
# 3  This class includes:\n- cereals, leguminous cr...  NaN     NaN      NaN
# 4                                                NaN  NaN     NaN      NaN

# %%
# function to print all content in one column as a string
def get_string(col):
    print(len(col))
    for i in range(len(col)):
        print(col.iloc[i],'\n')
# print out all content from two columns as pairs of strings        
def get_string2(cols):
    print(len(cols))
    for i in range(len(cols.iloc[:,0])):
        print(cols.iloc[i,0],'\n', cols.iloc[i,1],'\n')

# basic regex cleaning
def reg1(df):
    df = df.replace(r'\n-','',regex=True)
    df = df.replace(r'\n','',regex=True)
    df = df.replace(r'\t','',regex=True)
    df = df.replace(r'\r -','',regex=True)
    return df

COICOP = reg1(COICOP)
BEC = reg1(BEC)
SITC = reg1(SITC)
#CPA_COI = reg1(CPA_COI)
CPA = reg1(CPA)
CN  = reg1(CN)

BEC.head(20)
COICOP.head(20)
CPA.head()
# Out:
#      Order  Level     Code Parent  \
# 0  1208792      1        A    NaN
# 1  1208793      2       01      A
# 2  1208794      3     01.1     01
# 3  1208795      4    01.11   01.1
# 4  1208796      5  01.11.1  01.11
#
#                                          Description  \
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3  Cereals (except rice), leguminous crops and oi...
# 4                                              Wheat
#
#                                             Includes Also Rulings Excludes
# 0                                                NaN  NaN     NaN      NaN
# 1                                                NaN  NaN     NaN      NaN
# 2                                                NaN  NaN     NaN      NaN
# 3  This class includes: cereals, leguminous crops...  NaN     NaN      NaN
# 4                                                NaN  NaN     NaN      NaN

# %% [markdown]
# ## Cleaning CPA data

# %%
# first we combine columns with "includes" information
CPA1 = CPA.copy()
CPA1['Includes'] = CPA1['Includes'].fillna('')  + CPA1['Also'].fillna('') + CPA1['Rulings'].fillna('')

CPA['Excludes_cleaned'] = CPA.Excludes.str.replace('This(.*)excludes: ','') 
CPA['Includes_cleaned'] = CPA.Includes.str.replace('This(.*)includes: ','') 

CPA1 = CPA1.drop(['Also','Rulings','Includes','Excludes'], axis=1)
CPA1

# function to remove exclusions from the description which appear in brackets
def bracket_exclusions(df1,col_old):
    df= df1.copy()
    except_string = r'(\(except(.*?)\)|\(excl(.*?)\)|\(without(.*?)\)|\(not (.*?)\)|\(other than (.*?)\))'
    df['Excl_removed'] = ''
    df['Excl_removed'] = df[col_old].str.extract(except_string)
    df[col_old+'_excl_rem'] = df[col_old].str.replace(except_string, '')
    return df

CPA2 = bracket_exclusions(CPA1,'Description')
CPA2[CPA2['Excl_removed'].notnull()].head(60)
# Out:
#         Order  Level      Code   Parent  \
# 3     1208795      4     01.11     01.1
# 71    1208863      6  01.13.49  01.13.4
# 105   1208897      6  01.19.31  01.19.3
# 147   1208939      5   01.25.3    01.25
# 153   1208945      6  01.25.39  01.25.3
# 257   1209049      3      01.6       01
# 418   1209210      6  08.99.21  08.99.2
# 481   1209273      6  10.13.13  10.13.1
# 545   1209337      6  10.39.17  10.39.1
# 546   1209338      6  10.39.18  10.39.1
# 586   1209378      6  10.41.59  10.41.5
# 589   1209381      5   10.41.7    10.41
# 590   1209382      6  10.41.71  10.41.7
# 691   1209483      6  10.82.21  10.82.2
# 692   1209484      6  10.82.22  10.82.2
# 703   1209495      6  10.83.13  10.83.1
# 819   1209611      6  13.10.21  13.10.2
# 824   1209616      6  13.10.26  13.10.2
# 834   1209626      6  13.10.61  13.10.6
# 840   1209632      6  13.10.81  13.10.8
# 842   1209634      6  13.10.83  13.10.8
# 843   1209635      6  13.10.84  13.10.8
# 852   1209644      5   13.20.1    13.20
# 856   1209648      6  13.20.14  13.20.1
# 860   1209652      5   13.20.3    13.20
# 865   1209657      6  13.20.41  13.20.4
# 866   1209658      6  13.20.42  13.20.4
# 867   1209659      6  13.20.43  13.20.4
# 868   1209660      6  13.20.44  13.20.4
# 1064  1209856      6  15.12.13  15.12.1
# 1130  1209922      5   16.23.1    16.23
# 1187  1209979      6  17.12.42  17.12.4
# 1190  1209982      5   17.12.5    17.12
# 1199  1209991      6  17.12.74  17.12.7
# 1200  1209992      6  17.12.75  17.12.7
# 1203  1209995      6  17.12.78  17.12.7
# 1204  1209996      6  17.12.79  17.12.7
# 1351  1210143      6  20.13.42  20.13.4
# 2174  Tanks, casks, drums, cans, boxes and similar c...
# 2175  Tanks, casks, drums, cans (except those to be ...
# 2181  Aluminium casks, drums, cans, boxes and simila...
# 2193  Chain (except articulated link chain) and part...
# 2290  Radio broadcast receivers (except of a kind us...
# 2333  Microscopes (except optical microscopes) and d...
# 2344  Parts and accessories of microscopes (other th...
# 2384  Sheets and plates of polarising material; lens...
# 2389  Parts and accessories of liquid crystal device...
# 2458  Optical fibres and optical fibre bundles; opti...
# 2663  Office machinery and equipment (except compute...
# 2669  Office and accounting machinery manufacturing ...
# 2670  Office and accounting machinery manufacturing ...
# 2671  Sub-contracted operations as part of manufactu...
# 2986  Sailboats (except inflatable) for pleasure or ...
# 3075                  Parts of furniture (except seats)
#
#                                            Excl_removed  \
# 3                                         (except rice)
# 71              (without high starch or inulin content)
# 105                        (excluding sugar beet seeds)
# 147   (excluding wild edible nuts, groundnuts and co...
# 153   (excluding wild edible nuts, groundnuts and co...
# 257                        (except veterinary services)
# 418                     (excluding industrial diamonds)
# 481                   (excluding swine and bovine meat)
# 545                                   (except potatoes)
# 546                                   (except potatoes)
# 586                                  (except maize oil)
# 589                           (excluding triglycerides)
# 590                           (excluding triglycerides)
# 691                     (except sweetened cocoa powder)
# 692                     (except sweetened cocoa powder)
# 703                                     (not fermented)
# 819                                        (not thrown)
# 824                  (except flax, true hemp and ramie)
# 834                          (other than sewing thread)
# 840   (other than sewing thread, high tenacity yarn ...
# 842                          (other than sewing thread)
# 843                          (other than sewing thread)
# 852                            (except special fabrics)
# 856                  (except flax, true hemp and ramie)
# 860                            (except special fabrics)
# 865     (other than terry towelling and narrow fabrics)
# 866                         (other than narrow fabrics)
# 867                         (other than narrow fabrics)
# 868                         (other than narrow fabrics)
# 1064                                     (except metal)
# 1130                   (except prefabricated buildings)
# 1187  (other than that of a kind used for writing, p...
# 1190  (other than that of a kind used for writing, p...
# 1199  (other than that of a kind used for writing, p...
# 1200  (other than that of a kind used for writing, p...
# 1203  (other than that of a kind used for writing, p...
# 1204  (other than that of a kind used for writing, p...
# 1351                              (except of potassium)
# 1392             (excluding esters of hydrogen halides)
# 1730                              (except microspheres)
# 1849  (except setts, curbstones, flagstones, tiles, ...
# 1888      (except products of silicon-electrical steel)
# 2093       (other than for compressed or liquefied gas)
# 2141                              (except for machines)
# 2174                                    (excluding gas)
# 2175  (except those to be closed by soldering or cri...
# 2181                                    (excluding gas)
# 2193                    (except articulated link chain)
# 2290          (except of a kind used in motor vehicles)
# 2333                       (except optical microscopes)
# 2344                               (other than optical)
# 2384             (except of glass not optically worked)
# 2389                              (except laser diodes)
# 2458  (except those made up of individually sheathed...
# 2663        (except computers and peripheral equipment)
# 2669        (except computers and peripheral equipment)
# 2670        (except computers and peripheral equipment)
# 2671        (except computers and peripheral equipment)
# 2986                                (except inflatable)
# 3075                                     (except seats)
#
#                                    Description_excl_rem
# 3              Cereals , leguminous crops and oil seeds
# 71             Other root, bulb or tuberous vegetables
# 105             Beet seeds  and seeds for forage plants
# 147                                               Nuts
# 153                                         Other nuts
# 257         Agricultural and animal husbandry services
# 418   Precious and semi-precious stones , unworked o...
# 481   Other meat and edible meat offal, salted, in b...
# 545   Other vegetables , preserved otherwise than by...
# 546   Vegetables , fruit, nuts and other edible part...
# 586   Other oils and their fractions, refined but no...
# 589   Vegetable waxes ; degras; residues resulting f...
# 590                                    Vegetable waxes
# 691   Chocolate and food preparations containing coc...
# 692   Chocolate and food preparations containing coc...
# 703   Green tea , black tea (fermented) and partly f...
# 819                                           Raw silk
# 824   Jute and other textile fibres , processed but ...
# 834                                        Cotton yarn
# 840   Yarn of man made filaments, multiple or cabled...
# 842   Yarn  of synthetic staple fibres, containing <...
# 843                   Yarn  of artificial staple fibres
# 852   Woven fabrics , of natural fibres other than c...
# 856   Woven fabrics of jute and other textile bast f...
# 860   Woven fabrics , of man-made filaments and stap...
# 865            Woven pile fabrics and chenille fabrics
# 866   Terry towelling and similar woven terry fabric...
# 867   Other terry towelling and similar woven terry ...
# 868                                              Gauze
# 1064  Watch straps , watch bands and watch bracelets...
# 1130          Builders' joinery and carpentry , of wood
# 1187  Sulphite wrapping paper and other uncoated paper
# 1190                               Uncoated paperboard
# 1199  Kraft paper , coated with kaolin or with other...
# 1200  Kraft paperboard , coated with kaolin or with ...
# 1203  Inside grey paperboard , coated with kaolin or...
# 1204  Other paperboard , coated with kaolin or with ...
# 1351  Phosphinates, phosphonates, phosphates, polyph...
# 1392  Phosphoric esters and their salts or esters of...
# 1730  Glass in the mass, in balls , rods or tubes, u...
# 1849  Marble, travertine, alabaster, worked, and art...
# 1888  Flat rolled products of other alloy steel, not...
# 2093  Reservoirs, tanks, vats and similar containers...
# 2141            Knives  and scissors and blades thereof
# 2174  Tanks, casks, drums, cans, boxes and similar c...
# 2175  Tanks, casks, drums, cans , boxes and similar ...
# 2181  Aluminium casks, drums, cans, boxes and simila...
# 2193                           Chain  and parts thereof
# 2290  Radio broadcast receivers , whether or not com...
# 2333             Microscopes  and diffraction apparatus
# 2344  Parts and accessories of microscopes  and of d...
# 2384  Sheets and plates of polarising material; lens...
# 2389  Parts and accessories of liquid crystal device...
# 2458  Optical fibres and optical fibre bundles; opti...
# 2663                    Office machinery and equipment
# 2669  Office and accounting machinery manufacturing ...
# 2670  Office and accounting machinery manufacturing ...
# 2671  Sub-contracted operations as part of manufactu...
# 2986  Sailboats  for pleasure or sports, with or wit...
# 3075                                Parts of furniture

# %%
# function to remove phrases such as "except...", "excluding..." that appear at the end of the description

def reg_excludes(df1,col_old, excl_col):
    df= df1.copy()
    df['Temp'] = df[col_old]
    # sometimes there is "include" info after a phrase of the pattern "except... ;"
    except_string1a = r'(, except.*?;|, excl.*?;|, without.*;|,\bnot\b.*?;|\bnot\b.*?;| not\b.*?\)|, other than .*?;)'
    # sometimes there is "include" info after a phrase of the pattern  "except..., and"
    except_string1b = r'(, except.*?(, and)|, excl.*?(, and)|, without.*(, and))'
    # the phrases separated by a comma, eg "except..., " usually are followed by "exclude" info and occur at the end of the description.
    # however, phrases such as "not...", "other than..." which may have more "include" data later in the Description that must be left in.
    except_string1c = r'(, not.*?,)'
    # we now assume that the "except..." phrases continue to the end of the description field.
    except_string2 = '(, except.*|, excl(.*)|, without .*| not\s.*|, other than .*)'    
    #df[excl_col] = df[excl_col].fillna('')
    name = f'{excl_col}_{str(0)}'
    df[name] = df[excl_col].fillna('')
    i = 1
    except_strings = [except_string1a, except_string1b, except_string1c, except_string2]
    for s in except_strings:
        name = f'{excl_col}_{str(i)}'
        df[name] = ''
        df[name]= df['Temp'].str.extract(s, expand=True)
        df['Temp'] = df['Temp'].str.replace(s, '')
        i+=1
        print(name)
      #  get_string(df[df[name].notnull()][name])
    # create our new column with these items excluded
    df[col_old+'_excl_rem'] = df['Temp']
    # prepare dataframe to be returned
    df[excl_col] = df[excl_col+'_0'].fillna('') +df[excl_col+'_1'].fillna('')+df[excl_col+'_2'].fillna('')+df[excl_col+'_3'].fillna('') + df[excl_col+'_4'].fillna('')

    df2 = df.copy().drop(['Temp',col_old],axis=1)

    return df2

CPA2 = CPA2.rename(columns={'Description_excl_rem':'Descr'})
CPA3 = reg_excludes(CPA2,'Descr','Excl_removed')
display(len(CPA3[(CPA3.Excl_removed!='')&(CPA3.Excl_removed.notnull())]['Excl_removed']),
        CPA3.head())
# Out:
# Excl_removed_1
# Excl_removed_2
# Excl_removed_3
# Excl_removed_4
# 402
#      Order  Level     Code Parent  \
# 0  1208792      1        A    NaN
# 1  1208793      2       01      A
# 2  1208794      3     01.1     01
# 3  1208795      4    01.11   01.1
# 4  1208796      5  01.11.1  01.11
#
#                                          Description   Excl_removed  \
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3  Cereals (except rice), leguminous crops and oi...  (except rice)
# 4                                              Wheat
#
#   Excl_removed_0 Excl_removed_1 Excl_removed_2 Excl_removed_3 Excl_removed_4  \
# 0                           NaN            NaN            NaN            NaN
# 1                           NaN            NaN            NaN            NaN
# 2                           NaN            NaN            NaN            NaN
# 3  (except rice)            NaN            NaN            NaN            NaN
# 4                           NaN            NaN            NaN            NaN
#
#                                       Descr_excl_rem
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3           Cereals , leguminous crops and oil seeds
# 4                                              Wheat

# %%
CPA_cl = CPA3[['Order','Level','Code','Parent','Description','Descr_excl_rem']].rename(columns = {'Description':'Descr_old','Descr_excl_rem':'Descr'}).copy()
CPA_cl.to_csv('../data/processed/CPA_data_cleaned.csv', index=False)

# %%
# get the level 1s
level = {}
for i in range(1,7):
    level[i] = CPA_cl.copy().query(f"Level=={i}")[['Order','Level','Code','Parent','Descr']]
   # display(level[i].head())

#join 6 to its parent
level['5+6'] = level[5].merge(level[6].rename(columns={'Code':'Code_6','Parent':'Code'}), suffixes=('_5','_6'), on='Code',how='outer')
level['5+6']['Full_Descr'] = level['5+6'].Descr_5 + ', '+ level['5+6'].Descr_6

#get_string(level['5+6']['Full_Descr'].dropna())
level['5+6'].head(20)
# Out:
#     Order_5  Level_5     Code Parent                            Descr_5  \
# 0   1208796        5  01.11.1  01.11                              Wheat
