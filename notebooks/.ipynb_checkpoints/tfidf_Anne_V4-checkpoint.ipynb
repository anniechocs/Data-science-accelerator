# %% [markdown]
# # TF-IDF Example from scikit-learn docs
#
# Adapted from:
#
# https://scikit-learn.org/stable/auto_examples/model_selection/grid_search_text_feature_extraction.html#sphx-glr-auto-examples-model-selection-grid-search-text-feature-extraction-py

# %%
# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Peter Prettenhofer <peter.prettenhofer@gmail.com>
#         Mathieu Blondel <mathieu@mblondel.org>
# License: BSD 3 clause
from pprint import pprint
from time import time
import logging
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
print(__doc__)

# Display progress logs on stdout
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')
# Out:
# Automatically created module for IPython interactive environment

# %%
# Dimension reduction and clustering libraries
import umap
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score

# %%
CPA = pd.read_csv("../data/processed/CPA_tokenized.csv")
CPA.drop('Unnamed: 0', axis=1, inplace=True)
CPA.head()
# Out:
#      Order  Level     Code Parent  \
# 0  1208792      1        A    NaN
# 1  1208793      2       01      A
# 2  1208794      3     01.1     01
# 3  1208795      4    01.11   01.1
# 4  1208796      5  01.11.1  01.11
#
#                                                Descr  \
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3           Cereals , leguminous crops and oil seeds
# 4                                              Wheat
#
#                                           tokens
# 0   PRODUCTS OF AGRICULTURE FORESTRY AND FISHING
# 1  Products agriculture hunting related services
# 2                            Non-perennial crops
# 3             Cereals leguminous crops oil seeds
# 4                                          Wheat

# %%
# Create categories for Level 1 and Level 2 higherarchies
CPA2 = CPA.copy()
#get highest level of code
CPA2.loc[CPA2.Level !=1,'Category_2'] = CPA2[CPA2.Level !=1].Code.str.split('.').str.slice(0,1).str.join('')

# match up codes and parents
Code_parent = CPA2[CPA2.Level==2][['Parent','Category_2']].copy()
CPA2 = CPA2.merge(Code_parent.rename(columns={'Parent':'Category_1'}), on='Category_2', how='left')

# add in the Category_1 fileds for Level1
CPA2.loc[CPA2.Level==1, 'Category_1'] = CPA2.loc[CPA2.Level==1,'Code']

# we now set up a higher level for A10 indstry levels (10 categories)
update_dict0 = {'A':1,'F':3,'J':5, 'K':6, 'L':7,'M':8,'N':8}
update_dict = {**update_dict0,**dict.fromkeys(['B','C','D','E'],2),**dict.fromkeys(['G','H','I'],4),
               **dict.fromkeys(['O','P','Q'],9), **dict.fromkeys(['R','S','T','U'],10)}

CPA2['Category_0'] = CPA2.Category_1.replace(update_dict)
#CPA2 = CPA2.astype({'Category_0':int})
CPA2.head()
# Out:
# 2020-11-05 13:08:34,733 INFO NumExpr defaulting to 4 threads.
#      Order  Level     Code Parent  \
# 0  1208792      1        A    NaN
# 1  1208793      2       01      A
# 2  1208794      3     01.1     01
# 3  1208795      4    01.11   01.1
# 4  1208796      5  01.11.1  01.11
#
#                                                Descr  \
# 0      PRODUCTS OF AGRICULTURE, FORESTRY AND FISHING
# 1  Products of agriculture, hunting and related s...
# 2                                Non-perennial crops
# 3           Cereals , leguminous crops and oil seeds
# 4                                              Wheat
#
#                                           tokens Category_2 Category_1  \
# 0   PRODUCTS OF AGRICULTURE FORESTRY AND FISHING        NaN          A
# 1  Products agriculture hunting related services         01          A
# 2                            Non-perennial crops         01          A
# 3             Cereals leguminous crops oil seeds         01          A
# 4                                          Wheat         01          A
#
#    Category_0
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
# We now create an example based on Level 6 data
CPA_L6 = CPA2[CPA2.Level==6]
CPA_L6.head()
# Out:
#       Order  Level      Code   Parent        Descr       tokens Category_2  \
# 5   1208797      6  01.11.11  01.11.1  Durum wheat  Durum wheat         01
# 6   1208798      6  01.11.12  01.11.1        Wheat        Wheat         01
# 8   1208800      6  01.11.20  01.11.2        Maize        Maize         01
# 10  1208802      6  01.11.31  01.11.3       Barley       Barley         01
# 11  1208803      6  01.11.32  01.11.3          Rye          Rye         01
#
#    Category_1  Category_0
# 5           A           1
# 6           A           1
# 8           A           1
# 10          A           1
# 11          A           1

# %% [markdown]
# ## Notes on using TFIDF
# CountVectorizer implements both tokenization and occurrence counting in a single class
#
# In order to re-weight the count features into floating point values suitable for usage by a classifier it is very common to use the tf–idf transform.
#
# As tf–idf is very often used for text features, there is also another class called TfidfVectorizer that combines all the options of CountVectorizer and TfidfTransformer in a single model
#
# See also [scikit-learn on clustering](https://scikit-learn.org/stable/auto_examples/text/plot_document_clustering.html#sphx-glr-auto-examples-text-plot-document-clustering-py)

# %%
# now reapeat using the ngram character vectorizer
char_ngram_vectorizer = CountVectorizer(analyzer='char', ngram_range=(5, 5))
X3 = char_ngram_vectorizer.fit_transform(CPA_L6.tokens)

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
char_ngram_vectorizer.get_feature_names()[160:240]
# Out:
# [' bags', ' bake', ' baki', ' bala', ' bale', ' ball', ' bals', ' bamb', ' band', ' bank', ' barb', ' baro', ' bars', ' base', ' basi', ' bask', ' bast', ' bath', ' batt', ' bayo', ' beac', ' bead', ' beam', ' bean', ' bear', ' beau', ' bed ', ' bedr', ' beds', ' bee-', ' beer', ' beet', ' bein', ' belt', ' bend', ' bene', ' bent', ' berr', ' bert', ' beta', ' bett', ' beve', ' bib ', ' bicy', ' bide', ' bifu', ' bill', ' bind', ' bing', ' bino', ' bioh', ' biol', ' biot', ' bird', ' bisc', ' bitu', ' blac', ' blad', ' blan', ' blas', ' blaz', ' blin', ' bloc', ' bloo', ' blou', ' blow', ' boar', ' boat', ' bobb', ' bodi', ' bodk', ' body', ' boil', ' bold', ' bolt', ' bond', ' bone', ' book', ' boot', ' bora']

# %%
tfidf_pipeline1 = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
])
tfidf_pipeline2 = Pipeline([
    ('char_vect', char_ngram_vectorizer),
    ('tfidf', TfidfTransformer()),
])

# %%
tfidf_pipeline1.fit(CPA_L6.tokens)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer())])

# %%
tfidf_pipeline2.fit(CPA_L6.tokens)
# Out:
# Pipeline(steps=[('char_vect',
#                  CountVectorizer(analyzer='char', ngram_range=(5, 5))),
#                 ('tfidf', TfidfTransformer())])

# %% [markdown]
# # Simple visualisation - PCA

# %% [markdown]
# Adapted from
#
# https://scikit-learn.org/stable/auto_examples/decomposition/plot_pca_vs_lda.html#sphx-glr-auto-examples-decomposition-plot-pca-vs-lda-py

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.decomposition import PCA

X = tfidf_pipeline2.transform(CPA_L6.tokens).todense()
y = CPA_L6.Category_1
#target_names = ''

pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# plt.show()

# %%
df = CPA_L6.copy()
df['PCA_X'] = X_r[:,0]
df['PCA_Y'] = X_r[:,1]
df.head()
# Out:
#       Order  Level      Code   Parent        Descr       tokens Category_2  \
# 5   1208797      6  01.11.11  01.11.1  Durum wheat  Durum wheat         01
# 6   1208798      6  01.11.12  01.11.1        Wheat        Wheat         01
# 8   1208800      6  01.11.20  01.11.2        Maize        Maize         01
# 10  1208802      6  01.11.31  01.11.3       Barley       Barley         01
# 11  1208803      6  01.11.32  01.11.3          Rye          Rye         01
#
#    Category_1  Category_0     PCA_X     PCA_Y
# 5           A           1 -0.034505 -0.055988
# 6           A           1 -0.034628 -0.056391
# 8           A           1 -0.034390 -0.055593
# 10          A           1 -0.034188 -0.054952
# 11          A           1 -0.033753 -0.053561

# %%
my_palette = sns.color_palette("hls", 10)
plt.figure(figsize=(10,10))
sns.scatterplot(data=df,x='PCA_X', y='PCA_Y', hue='Category_0', palette=my_palette)
# Out:
# <AxesSubplot:xlabel='PCA_X', ylabel='PCA_Y'>

# %% [markdown]
# # T-SNE visualisation
#
# Adapted from: https://www.kaggle.com/premvardhan/amazon-fine-food-review-tsne-visualization
#
# Not so good above 4 dimensions

# %%
from sklearn.manifold import TSNE


X = tfidf_pipeline2.transform(CPA_L6.tokens).todense()
y = CPA_L6.Category_1


pca = PCA(n_components=10)
X_r = pca.fit(X).transform(X)

model = TSNE(n_components=2, random_state=0, perplexity=50, n_iter=5000, verbose=10)

tsne_data = model.fit_transform(X_r)

tsne_df = pd.DataFrame(data=tsne_data, columns=("dim1", "dim2"))
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 3218 samples in 0.005s...
# [t-SNE] Computed neighbors for 3218 samples in 0.336s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3218
# [t-SNE] Computed conditional probabilities for sample 2000 / 3218
# [t-SNE] Computed conditional probabilities for sample 3000 / 3218
# [t-SNE] Computed conditional probabilities for sample 3218 / 3218
# [t-SNE] Mean sigma: 0.006901
# [t-SNE] Computed conditional probabilities in 0.409s
# [t-SNE] Iteration 50: error = 71.6750412, gradient norm = 0.0735622 (50 iterations in 1.151s)
# [t-SNE] Iteration 100: error = 64.4563751, gradient norm = 0.0095906 (50 iterations in 0.891s)
# [t-SNE] Iteration 150: error = 63.6804352, gradient norm = 0.0051729 (50 iterations in 0.827s)
# [t-SNE] Iteration 200: error = 63.4056015, gradient norm = 0.0041389 (50 iterations in 0.814s)
# [t-SNE] Iteration 250: error = 63.2228699, gradient norm = 0.0075359 (50 iterations in 0.882s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.222870
# [t-SNE] Iteration 300: error = 1.0784622, gradient norm = 0.0010016 (50 iterations in 0.877s)
# [t-SNE] Iteration 350: error = 0.8378787, gradient norm = 0.0003617 (50 iterations in 0.869s)
# [t-SNE] Iteration 400: error = 0.7572241, gradient norm = 0.0001952 (50 iterations in 0.842s)
# [t-SNE] Iteration 450: error = 0.7201455, gradient norm = 0.0001568 (50 iterations in 0.838s)
# [t-SNE] Iteration 500: error = 0.7025986, gradient norm = 0.0001175 (50 iterations in 0.844s)
# [t-SNE] Iteration 550: error = 0.6927830, gradient norm = 0.0001104 (50 iterations in 0.831s)
# [t-SNE] Iteration 600: error = 0.6880453, gradient norm = 0.0000980 (50 iterations in 0.846s)
# [t-SNE] Iteration 650: error = 0.6847378, gradient norm = 0.0000887 (50 iterations in 0.836s)
# [t-SNE] Iteration 700: error = 0.6815553, gradient norm = 0.0000811 (50 iterations in 0.843s)
# [t-SNE] Iteration 750: error = 0.6788357, gradient norm = 0.0000800 (50 iterations in 0.823s)
# [t-SNE] Iteration 800: error = 0.6767523, gradient norm = 0.0000673 (50 iterations in 0.821s)
# [t-SNE] Iteration 850: error = 0.6745382, gradient norm = 0.0000739 (50 iterations in 0.840s)
# [t-SNE] Iteration 900: error = 0.6728429, gradient norm = 0.0000660 (50 iterations in 0.809s)
# [t-SNE] Iteration 950: error = 0.6713012, gradient norm = 0.0000634 (50 iterations in 0.845s)
# [t-SNE] Iteration 1000: error = 0.6700915, gradient norm = 0.0000591 (50 iterations in 0.813s)
# [t-SNE] Iteration 1050: error = 0.6691245, gradient norm = 0.0000609 (50 iterations in 0.814s)
# [t-SNE] Iteration 1100: error = 0.6681856, gradient norm = 0.0000572 (50 iterations in 0.830s)
# [t-SNE] Iteration 1150: error = 0.6672815, gradient norm = 0.0000586 (50 iterations in 0.816s)
# [t-SNE] Iteration 1200: error = 0.6665697, gradient norm = 0.0000642 (50 iterations in 0.832s)
# [t-SNE] Iteration 1250: error = 0.6658246, gradient norm = 0.0000588 (50 iterations in 0.805s)
# [t-SNE] Iteration 1300: error = 0.6651409, gradient norm = 0.0000576 (50 iterations in 0.807s)
# [t-SNE] Iteration 1350: error = 0.6645412, gradient norm = 0.0000630 (50 iterations in 0.839s)
# [t-SNE] Iteration 1400: error = 0.6641438, gradient norm = 0.0000544 (50 iterations in 0.821s)
# [t-SNE] Iteration 1450: error = 0.6636609, gradient norm = 0.0000582 (50 iterations in 0.841s)
# [t-SNE] Iteration 1500: error = 0.6631651, gradient norm = 0.0000573 (50 iterations in 0.812s)
# [t-SNE] Iteration 1550: error = 0.6626030, gradient norm = 0.0000525 (50 iterations in 0.815s)
# [t-SNE] Iteration 1600: error = 0.6620710, gradient norm = 0.0000463 (50 iterations in 0.831s)
# [t-SNE] Iteration 1650: error = 0.6617391, gradient norm = 0.0000476 (50 iterations in 0.812s)
# [t-SNE] Iteration 1700: error = 0.6612520, gradient norm = 0.0000457 (50 iterations in 0.843s)
# [t-SNE] Iteration 1750: error = 0.6609114, gradient norm = 0.0000547 (50 iterations in 0.816s)
# [t-SNE] Iteration 1800: error = 0.6607646, gradient norm = 0.0000565 (50 iterations in 0.818s)
# [t-SNE] Iteration 1850: error = 0.6604894, gradient norm = 0.0000446 (50 iterations in 0.829s)
# [t-SNE] Iteration 1900: error = 0.6601470, gradient norm = 0.0000419 (50 iterations in 0.822s)
# [t-SNE] Iteration 1950: error = 0.6597751, gradient norm = 0.0000440 (50 iterations in 0.836s)
# [t-SNE] Iteration 2000: error = 0.6595355, gradient norm = 0.0000395 (50 iterations in 0.831s)
# [t-SNE] Iteration 2050: error = 0.6592851, gradient norm = 0.0000451 (50 iterations in 0.834s)
# [t-SNE] Iteration 2100: error = 0.6590363, gradient norm = 0.0000406 (50 iterations in 0.832s)
# [t-SNE] Iteration 2150: error = 0.6588596, gradient norm = 0.0000399 (50 iterations in 0.822s)
# [t-SNE] Iteration 2200: error = 0.6586792, gradient norm = 0.0000430 (50 iterations in 0.836s)
# [t-SNE] Iteration 2250: error = 0.6584767, gradient norm = 0.0000448 (50 iterations in 0.820s)
# [t-SNE] Iteration 2300: error = 0.6582712, gradient norm = 0.0000384 (50 iterations in 0.824s)
# [t-SNE] Iteration 2350: error = 0.6581197, gradient norm = 0.0000375 (50 iterations in 0.834s)
# [t-SNE] Iteration 2400: error = 0.6579606, gradient norm = 0.0000397 (50 iterations in 0.820s)
# [t-SNE] Iteration 2450: error = 0.6577169, gradient norm = 0.0000429 (50 iterations in 0.831s)
# [t-SNE] Iteration 2500: error = 0.6575231, gradient norm = 0.0000423 (50 iterations in 0.827s)
# [t-SNE] Iteration 2550: error = 0.6574400, gradient norm = 0.0000396 (50 iterations in 0.833s)
# [t-SNE] Iteration 2600: error = 0.6572927, gradient norm = 0.0000382 (50 iterations in 0.826s)
# [t-SNE] Iteration 2650: error = 0.6570616, gradient norm = 0.0000406 (50 iterations in 0.843s)
# [t-SNE] Iteration 2700: error = 0.6567841, gradient norm = 0.0000413 (50 iterations in 0.831s)
# [t-SNE] Iteration 2750: error = 0.6565289, gradient norm = 0.0000410 (50 iterations in 0.819s)
# [t-SNE] Iteration 2800: error = 0.6563038, gradient norm = 0.0000420 (50 iterations in 0.830s)
# [t-SNE] Iteration 2850: error = 0.6561754, gradient norm = 0.0000377 (50 iterations in 0.812s)
# [t-SNE] Iteration 2900: error = 0.6561214, gradient norm = 0.0000461 (50 iterations in 0.849s)
# [t-SNE] Iteration 2950: error = 0.6559595, gradient norm = 0.0000470 (50 iterations in 0.838s)
# [t-SNE] Iteration 3000: error = 0.6559544, gradient norm = 0.0000438 (50 iterations in 0.819s)
# [t-SNE] Iteration 3050: error = 0.6558475, gradient norm = 0.0000415 (50 iterations in 0.836s)
# [t-SNE] Iteration 3100: error = 0.6557024, gradient norm = 0.0000393 (50 iterations in 0.822s)
# [t-SNE] Iteration 3150: error = 0.6555456, gradient norm = 0.0000431 (50 iterations in 0.829s)
# [t-SNE] Iteration 3200: error = 0.6553776, gradient norm = 0.0000419 (50 iterations in 0.847s)
# [t-SNE] Iteration 3250: error = 0.6552681, gradient norm = 0.0000464 (50 iterations in 0.824s)
# [t-SNE] Iteration 3300: error = 0.6551624, gradient norm = 0.0000409 (50 iterations in 0.834s)
# [t-SNE] Iteration 3350: error = 0.6550273, gradient norm = 0.0000359 (50 iterations in 0.819s)
# [t-SNE] Iteration 3400: error = 0.6548998, gradient norm = 0.0000434 (50 iterations in 0.819s)
# [t-SNE] Iteration 3450: error = 0.6548537, gradient norm = 0.0000452 (50 iterations in 0.842s)
# [t-SNE] Iteration 3500: error = 0.6547008, gradient norm = 0.0000426 (50 iterations in 0.831s)
# [t-SNE] Iteration 3550: error = 0.6546590, gradient norm = 0.0000405 (50 iterations in 0.843s)
# [t-SNE] Iteration 3600: error = 0.6545070, gradient norm = 0.0000433 (50 iterations in 0.827s)
# [t-SNE] Iteration 3650: error = 0.6544006, gradient norm = 0.0000418 (50 iterations in 0.841s)
# [t-SNE] Iteration 3700: error = 0.6542721, gradient norm = 0.0000422 (50 iterations in 0.849s)
# [t-SNE] Iteration 3750: error = 0.6542110, gradient norm = 0.0000449 (50 iterations in 0.824s)
# [t-SNE] Iteration 3800: error = 0.6540458, gradient norm = 0.0000473 (50 iterations in 0.840s)
# [t-SNE] Iteration 3850: error = 0.6539846, gradient norm = 0.0000381 (50 iterations in 0.830s)
# [t-SNE] Iteration 3900: error = 0.6538830, gradient norm = 0.0000391 (50 iterations in 0.849s)
# [t-SNE] Iteration 3950: error = 0.6537426, gradient norm = 0.0000362 (50 iterations in 0.819s)
# [t-SNE] Iteration 4000: error = 0.6536608, gradient norm = 0.0000363 (50 iterations in 0.828s)
# [t-SNE] Iteration 4050: error = 0.6535119, gradient norm = 0.0000348 (50 iterations in 0.838s)
# [t-SNE] Iteration 4100: error = 0.6534460, gradient norm = 0.0000395 (50 iterations in 0.821s)
# [t-SNE] Iteration 4150: error = 0.6534361, gradient norm = 0.0000398 (50 iterations in 0.843s)
# [t-SNE] Iteration 4200: error = 0.6533785, gradient norm = 0.0000416 (50 iterations in 0.825s)
# [t-SNE] Iteration 4250: error = 0.6532383, gradient norm = 0.0000342 (50 iterations in 0.822s)
# [t-SNE] Iteration 4300: error = 0.6531283, gradient norm = 0.0000420 (50 iterations in 0.840s)
# [t-SNE] Iteration 4350: error = 0.6531177, gradient norm = 0.0000444 (50 iterations in 0.837s)
# [t-SNE] Iteration 4400: error = 0.6530646, gradient norm = 0.0000390 (50 iterations in 0.841s)
# [t-SNE] Iteration 4450: error = 0.6529979, gradient norm = 0.0000397 (50 iterations in 0.836s)
# [t-SNE] Iteration 4500: error = 0.6530548, gradient norm = 0.0000407 (50 iterations in 0.836s)
# [t-SNE] Iteration 4550: error = 0.6530063, gradient norm = 0.0000385 (50 iterations in 0.846s)
# [t-SNE] Iteration 4600: error = 0.6528698, gradient norm = 0.0000302 (50 iterations in 0.843s)
# [t-SNE] Iteration 4650: error = 0.6527939, gradient norm = 0.0000310 (50 iterations in 0.842s)
# [t-SNE] Iteration 4700: error = 0.6527628, gradient norm = 0.0000302 (50 iterations in 0.831s)
# [t-SNE] Iteration 4750: error = 0.6527219, gradient norm = 0.0000317 (50 iterations in 0.836s)
# [t-SNE] Iteration 4800: error = 0.6526138, gradient norm = 0.0000249 (50 iterations in 0.891s)
# [t-SNE] Iteration 4850: error = 0.6526077, gradient norm = 0.0000337 (50 iterations in 0.845s)
# [t-SNE] Iteration 4900: error = 0.6525090, gradient norm = 0.0000327 (50 iterations in 0.846s)
# [t-SNE] Iteration 4950: error = 0.6524524, gradient norm = 0.0000308 (50 iterations in 0.831s)
# [t-SNE] Iteration 5000: error = 0.6524087, gradient norm = 0.0000342 (50 iterations in 0.844s)
# [t-SNE] KL divergence after 5000 iterations: 0.652409

# %%
df2 = CPA_L6.copy()
df2['dim1'] = tsne_data[:,0]
df2['dim2'] = tsne_data[:,1]
df2.head()
# Out:
#       Order  Level      Code   Parent        Descr       tokens Category_2  \
# 5   1208797      6  01.11.11  01.11.1  Durum wheat  Durum wheat         01
# 6   1208798      6  01.11.12  01.11.1        Wheat        Wheat         01
# 8   1208800      6  01.11.20  01.11.2        Maize        Maize         01
# 10  1208802      6  01.11.31  01.11.3       Barley       Barley         01
# 11  1208803      6  01.11.32  01.11.3          Rye          Rye         01
#
#    Category_1  Category_0       dim1      dim2
# 5           A           1 -22.904440  2.532039
# 6           A           1 -23.999657  2.910363
# 8           A           1 -21.856501  1.788245
# 10          A           1 -19.600891 -0.038710
# 11          A           1 -17.704933 -1.303674

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df2,x='dim1', y='dim2', hue='Category_0',  palette=my_palette)
# Out:
# <AxesSubplot:xlabel='dim1', ylabel='dim2'>

# %%
#sns.FacetGrid(tsne_df, hue="category", size=6, legend=None).map(plt.scatter, 'dim1', 'dim2').add_legend()
sns.FacetGrid(df2, hue="Category_0", height=10).map(plt.scatter, 'dim1', 'dim2').add_legend()
plt.title("T-SNE for TF-IDF");

# %%
import sklearn.metrics.pairwise

# %%
distance_matrix = sklearn.metrics.pairwise.cosine_distances(X)

# %%
plt.set_cmap("viridis")
plt.figure(figsize=(10, 10))
plt.imshow(1-distance_matrix)
plt.colorbar();

# %%
test = distance_matrix.flatten()
sns.displot(test[test<0.9])

# %%
plt.figure(figsize=(10, 10))
sns.displot(distance_matrix.flatten())

# %% [markdown]
# ## Discussion points:
# * Curse of dimensionality
# * Uni-modal pairwise distance distribution
# * Dimensionality reduction
# * Clustering e.g. HDBSCAN

# %% [markdown]
# ## UMAP example

# %%
# u-map
# Dimension reduction and clustering libraries
import umap
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score

# %%
sns.set(style='white', rc={'figure.figsize':(10,8)})

# %%
standard_embedding = umap.UMAP(random_state=42).fit_transform(df2.dim1, df2.dim2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-33ca126b52fb> in <module>
# ----> 1 df2.reshape(-1, 1)
#       2 standard_embedding = umap.UMAP(random_state=42).fit_transform(df2.dim1, df2.dim2)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5134             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5135                 return self[name]
# -> 5136             return object.__getattribute__(self, name)
#    5137
#    5138     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'
